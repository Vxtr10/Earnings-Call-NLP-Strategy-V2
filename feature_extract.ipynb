# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
numblist = [1,2,3,4,5,6,7]

sectorlist = ["automobiles", "banks", "capital-goods", "commercial-services", 
"consumer-durables", "consumer-retailing", "consumer-services", "diversified-financials",
"energy", "food-beverage-tobacco", "healthcare", "household", "insurance", "materials", "media", 
"pharmaceuticals-biotech", "real-estate", "retail", "semiconductors", "software",
"tech", "telecom", "transportation", "utilities"]

urllist = []

for sector in sectorlist:
    for number in numblist:
        urllist.append('https://simplywall.st/stocks/us/' + sector + '/market-cap-large?page=' + str(number))


count = 0
count2 = 0
df = pd.DataFrame(columns=['href','ticker'])

for i in range(0, len(urllist)+1):
    if count == 7:   
            count = 0
            df.to_csv('hrefs/ref_' + (sectorlist[count2]) + '.csv', index=False)
            count2 += 1
            df = pd.DataFrame(columns=['href','ticker'])
        
    try:
        url = urllist[i]
        print(url)
        count+=1
        html_text = requests.get(url).text
        
        soup = BeautifulSoup(html_text, "html.parser")
        body = soup.find('tbody').find_all('tr')

        for j in body:
            temp = j.find_all('td')[1]
            insert_row = {"href": (temp.a['href']), "ticker": ''.join(temp.find('b').contents)}
            df = pd.concat([df, pd.DataFrame([insert_row])])

    except:
        continue
# Out:
# https://simplywall.st/stocks/us/software/market-cap-large?page=1
# https://simplywall.st/stocks/us/software/market-cap-large?page=2
# https://simplywall.st/stocks/us/software/market-cap-large?page=3
# https://simplywall.st/stocks/us/software/market-cap-large?page=4
# https://simplywall.st/stocks/us/software/market-cap-large?page=5
# https://simplywall.st/stocks/us/software/market-cap-large?page=6
# https://simplywall.st/stocks/us/software/market-cap-large?page=7
# https://simplywall.st/stocks/us/tech/market-cap-large?page=1
# https://simplywall.st/stocks/us/tech/market-cap-large?page=2
# https://simplywall.st/stocks/us/tech/market-cap-large?page=3
# https://simplywall.st/stocks/us/tech/market-cap-large?page=4
# https://simplywall.st/stocks/us/tech/market-cap-large?page=5
# https://simplywall.st/stocks/us/tech/market-cap-large?page=6
# https://simplywall.st/stocks/us/tech/market-cap-large?page=7
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=1
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=2
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=3
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=4
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=5
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=6
# https://simplywall.st/stocks/us/telecom/market-cap-large?page=7
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=1
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=2
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=3
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=4
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=5
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=6
# https://simplywall.st/stocks/us/transportation/market-cap-large?page=7
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=1
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=2
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=3
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=4
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=5
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=6
# https://simplywall.st/stocks/us/utilities/market-cap-large?page=7

# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# sectorlist = ["automobiles", "banks", "capital-goods", "commercial-services", 
# "consumer-durables", "consumer-retailing", "consumer-services", "diversified-financials",
# "energy", "food-beverage-tobacco", "healthcare", "household", "insurance", "materials", "media", 
# "pharmaceuticals-biotech", "real-estate", "retail", "semiconductors", "software",
# "tech", "telecom", "transportation", "utilities"]

sectorlist = ["pharmaceuticals-biotech", "real-estate", "retail", "semiconductors", "software",
"tech", "telecom", "transportation", "utilities"]

for sector in sectorlist:
    df = pd.read_csv('hrefs/ref_' + (sector) + '.csv')
    
    hrefs = df["href"]
    df_fair_value = pd.DataFrame()
    for href in hrefs:
        time.sleep(1.5)
        url = "https://simplywall.st" + str(href) + "/valuation"
        print(url)
        html_text = requests.get(url).text
        soup = BeautifulSoup(html_text, "html.parser")
        body = soup.find_all('blockquote')
        count = 0
        fair_value = np.NaN
        for i in body:
            count += 1
            if count < 25:
                try:
                    q = ''.join(i.find('p').find_all('span')[3].contents)
                    if q[2] == "$":
                        fair_value = q
                except:
                    continue
            else:
                break
        insert_row = {"fair_value": fair_value}
        
        df_fair_value = pd.concat([df_fair_value, pd.DataFrame([insert_row])])
        print(fair_value)
    df_initial = pd.read_csv('hrefs/ref_'+sector+'.csv')
    
    
    #df_initial = df_initial.drop('fair_value', axis=1)
   
    temp2 = df_fair_value.to_numpy()
    
    df_initial.insert(loc=2, column="fair_value", value=temp2)
    df_initial.to_csv('hrefs/ref_' + (sector) + '.csv', index=False)
# Out:
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-jnj/johnson-johnson/valuation
#  ($213.78)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-lly/eli-lilly/valuation
#  ($344.57)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-pfe/pfizer/valuation
#  ($104.09)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-abbv/abbvie/valuation
#  ($308.36)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-mrk/merck/valuation
#  ($209.73)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-tmo/thermo-fisher-scientific/valuation
#  ($790.84)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-dhr/danaher/valuation
#  ($274.02)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-bmy/bristol-myers-squibb/valuation
#  ($126.61)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-amgn/amgen/valuation
#  ($426.9)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-gild/gilead-sciences/valuation
#  ($148.11)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-regn/regeneron-pharmaceuticals/valuation
#  ($770.66)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-vrtx/vertex-pharmaceuticals/valuation
#  ($493.82)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-zts/zoetis/valuation
#  ($169.91)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-mrna/moderna/valuation
#  ($31.58)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-a/agilent-technologies/valuation
#  ($111.28)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-iqv/iqvia-holdings/valuation
#  ($302.01)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-biib/biogen/valuation
#  ($379.5)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ilmn/illumina/valuation
#  ($357.86)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bntx/biontech/valuation
#  ($90.27)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-mtd/mettler-toledo-international/valuation
#  ($933.01)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rprx/royalty-pharma/valuation
#  ($103.25)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-alny/alnylam-pharmaceuticals/valuation
#  ($504.25)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-sgen/seagen/valuation
#  ($318.41)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bgne/beigene/valuation
#  ($686.03)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bgne/beigene/valuation
#  ($686.03)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-wst/west-pharmaceutical-services/valuation
#  ($197.01)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-iclr/icon/valuation
#  ($281.21)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-hznp/horizon-therapeutics/valuation
#  ($205.57)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-incy/incyte/valuation
#  ($233.2)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-pki/perkinelmer/valuation
#  ($225.71)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bmrn/biomarin-pharmaceutical/valuation
#  ($198.34)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-avtr/avantor/valuation
#  ($23.87)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-vtrs/viatris/valuation
#  ($43.61)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-tech/bio-techne/valuation
#  ($326.52)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-bio/bio-rad-laboratories/valuation
#  ($384.33)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-crl/charles-river-laboratories-international/valuation
#  ($231.68)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-uthr/united-therapeutics/valuation
#  ($678.57)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-nbix/neurocrine-biosciences/valuation
#  ($297.16)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-qgen/qiagen/valuation
#  ($40.12)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rgen/repligen/valuation
#  ($179.83)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-teva/teva-pharmaceutical-industries/valuation
#  ($41.51)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-brkr/bruker/valuation
#  ($43.96)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-jazz/jazz-pharmaceuticals/valuation
#  ($561.29)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-srpt/sarepta-therapeutics/valuation
#  ($732.44)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-legn/legend-biotech/valuation
#  ($230.38)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-ctlt/catalent/valuation
#  ($62.91)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-krtx/karuna-therapeutics/valuation
#  ($1130.07)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-exas/exact-sciences/valuation
#  ($149.9)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-asnd/ascendis-pharma/valuation
#  ($21.83)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-halo/halozyme-therapeutics/valuation
#  ($153.15)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-medp/medpace-holdings/valuation
#  ($362.38)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ions/ionis-pharmaceuticals/valuation
#  ($176.3)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-ogn/organon/valuation
#  ($117.23)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-elan/elanco-animal-health/valuation
#  ($62.33)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-exel/exelixis/valuation
#  ($42.08)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-apls/apellis-pharmaceuticals/valuation
#  ($435.49)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-itci/intra-cellular-therapies/valuation
#  ($406.03)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-gbt/global-blood-therapeutics/valuation
#  ($195.86)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-prgo/perrigo/valuation
#  ($86.25)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cere/cerevel-therapeutics-holdings/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-txg/10x-genomics/valuation
#  ($60.48)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-crsp/crispr-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ntla/intellia-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-dnli/denali-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-mrtx/mirati-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-alks/alkermes/valuation
#  ($57.97)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-stvn/stevanato-group/valuation
#  ($54.44)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-tptx/turning-point-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-roiv/roivant-sciences/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ccxi/chemocentryx/valuation
#  ($235.72)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ntra/natera/valuation
#  ($15.31)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cytk/cytokinetics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-abcl/abcellera-biologics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-arwr/arrowhead-pharmaceuticals/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-vir/vir-biotechnology/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-mrvi/maravai-lifesciences-holdings/valuation
#  ($9.06)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-pcvx/vaxcyte/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-azta/azenta/valuation
#  ($124.98)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-hrmy/harmony-biosciences-holdings/valuation
#  ($334.78)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-synh/syneos-health/valuation
#  ($92.53)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-fold/amicus-therapeutics/valuation
#  ($38.4)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-beam/beam-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-zlab/zai-lab/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-pbh/prestige-consumer-healthcare/valuation
#  ($120.23)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cort/corcept-therapeutics/valuation
#  ($59.5)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-prta/prothena/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ptct/ptc-therapeutics/valuation
#  ($226.26)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-bhc/bausch-health-companies/valuation
#  ($58.5)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-acad/acadia-pharmaceuticals/valuation
#  ($76.76)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rare/ultragenyx-pharmaceutical/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-insm/insmed/valuation
#  ($27.77)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-imcr/immunocore-holdings/valuation
#  ($104.76)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bpmc/blueprint-medicines/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-myov/myovant-sciences/valuation
#  ($207.92)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-axsm/axsome-therapeutics/valuation
#  ($427.48)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-prok/prokidney/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-arvn/arvinas/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rlay/relay-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bcrx/biocryst-pharmaceuticals/valuation
#  ($60.76)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-pcrx/pacira-biosciences/valuation
#  ($214.98)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-olk/olink-holding/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-tlry/tilray-brands/valuation
#  ($7.53)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-amlx/amylyx-pharmaceuticals/valuation
#  ($240.96)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-isee/iveric-bio/valuation
#  ($161.5)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-pacb/pacific-biosciences-of-california/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-xene/xenon-pharmaceuticals/valuation
#  ($7.01)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rxrx/recursion-pharmaceuticals/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ibrx/immunitybio/valuation
#  ($65.24)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-sage/sage-therapeutics/valuation
#  ($64.35)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-fate/fate-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nyse-rcus/arcus-biosciences/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rxdx/prometheus-biosciences/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-vcyt/veracyte/valuation
#  ($2.9)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-krys/krystal-biotech/valuation
#  ($446.84)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-shc/sotera-health/valuation
#  ($23.54)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-ctkb/cytek-biosciences/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-twst/twist-bioscience/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rvmd/revolution-medicines/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rvnc/revance-therapeutics/valuation
#  ($164)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-akro/akero-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-eqrx/eqrx/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-supn/supernus-pharmaceuticals/valuation
#  ($149.73)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-xncr/xencor/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-irwd/ironwood-pharmaceuticals/valuation
#  ($29.28)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cldx/celldex-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-nvax/novavax/valuation
#  ($167.98)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-nuvl/nuvalent/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-prme/prime-medicine/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-kymr/kymera-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-mygn/myriad-genetics/valuation
#  ($17.2)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-dvax/dynavax-technologies/valuation
#  ($35.8)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-imvt/immunovant/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cprx/catalyst-pharmaceuticals/valuation
#  ($37.69)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-alvo/alvotech/valuation
#  ($27.35)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-agio/agios-pharmaceuticals/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-dice/dice-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-dawn/day-one-biopharmaceuticals/valuation
#  ($44.16)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-bbio/bridgebio-pharma/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-fgen/fibrogen/valuation
#  ($18.83)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-vtyx/ventyx-biosciences/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-swtx/springworks-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-verv/verve-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rytm/rhythm-pharmaceuticals/valuation
#  ($59.32)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-tvtx/travere-therapeutics/valuation
#  ($634.62)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-sndx/syndax-pharmaceuticals/valuation
#  ($162.28)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-kdny/chinook-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-inbx/inhibrx/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-sava/cassava-sciences/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-lgnd/ligand-pharmaceuticals/valuation
#  ($156.71)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-reta/reata-pharmaceuticals/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cvac/curevac/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-amph/amphastar-pharmaceuticals/valuation
#  ($63.04)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-allo/allogene-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-iova/iovance-biotherapeutics/valuation
#  ($83.04)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-rckt/rocket-pharmaceuticals/valuation
#  ($145.65)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-srra/sierra-oncology/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-kros/keros-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-adpt/adaptive-biotechnologies/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-neo/neogenomics/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-imgn/immunogen/valuation
#  ($3.72)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-lyel/lyell-immunopharma/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-cinc/cincor-pharma/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-arqt/arcutis-biotherapeutics/valuation
#  ($249.02)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-mdgl/madrigal-pharmaceuticals/valuation
#  ($20.49)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-morf/morphic-holding/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-zntl/zentalis-pharmaceuticals/valuation
# nan
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-tgtx/tg-therapeutics/valuation
#  ($141.95)
# https://simplywall.st/stocks/us/pharmaceuticals-biotech/nasdaq-acrs/aclaris-therapeutics/valuation
# nan
# https://simplywall.st/stocks/us/real-estate/nyse-pld/prologis/valuation
#  ($162.02)
# https://simplywall.st/stocks/us/real-estate/nyse-amt/american-tower/valuation
#  ($320.27)
# https://simplywall.st/stocks/us/real-estate/nasdaq-eqix/equinix/valuation
#  ($1055.08)
# https://simplywall.st/stocks/us/real-estate/nyse-cci/crown-castle/valuation
#  ($165.81)
# https://simplywall.st/stocks/us/real-estate/nyse-psa/public-storage/valuation
#  ($461.42)
# https://simplywall.st/stocks/us/real-estate/nyse-spg/simon-property-group/valuation
#  ($233.72)
# https://simplywall.st/stocks/us/real-estate/nyse-o/realty-income/valuation
#  ($124.42)
# https://simplywall.st/stocks/us/real-estate/nyse-well/welltower/valuation
#  ($92.13)
# https://simplywall.st/stocks/us/real-estate/nyse-dlr/digital-realty-trust/valuation
#  ($187.33)
# https://simplywall.st/stocks/us/real-estate/nasdaq-sbac/sba-communications/valuation
#  ($315.36)
# https://simplywall.st/stocks/us/real-estate/nyse-vici/vici-properties/valuation
#  ($62.71)
# https://simplywall.st/stocks/us/real-estate/nyse-are/alexandria-real-estate-equities/valuation
#  ($181.53)
# https://simplywall.st/stocks/us/real-estate/nyse-eqr/equity-residential/valuation
#  ($81.09)
# https://simplywall.st/stocks/us/real-estate/nyse-cbre/cbre-group/valuation
#  ($158.22)
# https://simplywall.st/stocks/us/real-estate/nyse-wy/weyerhaeuser/valuation
#  ($113.47)
# https://simplywall.st/stocks/us/real-estate/nyse-avb/avalonbay-communities/valuation
#  ($273.83)
# https://simplywall.st/stocks/us/real-estate/nyse-exr/extra-space-storage/valuation
#  ($222.12)
# https://simplywall.st/stocks/us/real-estate/nyse-invh/invitation-homes/valuation
#  ($36.93)
# https://simplywall.st/stocks/us/real-estate/nyse-maa/mid-america-apartment-communities/valuation
#  ($222.18)
# https://simplywall.st/stocks/us/real-estate/nyse-vtr/ventas/valuation
#  ($59.68)
# https://simplywall.st/stocks/us/real-estate/nyse-sui/sun-communities/valuation
#  ($173.3)
# https://simplywall.st/stocks/us/real-estate/nyse-beke/ke-holdings/valuation
#  ($8.93)
# https://simplywall.st/stocks/us/real-estate/nyse-wpc/w-p-carey/valuation
#  ($149)
# https://simplywall.st/stocks/us/real-estate/nyse-irm/iron-mountain/valuation
#  ($116.39)
# https://simplywall.st/stocks/us/real-estate/nyse-beke/ke-holdings/valuation
#  ($8.93)
# https://simplywall.st/stocks/us/real-estate/nyse-udr/udr/valuation
#  ($61.14)
# https://simplywall.st/stocks/us/real-estate/nyse-kim/kimco-realty/valuation
#  ($29.63)
# https://simplywall.st/stocks/us/real-estate/nyse-peak/healthpeak-properties/valuation
#  ($33.79)
# https://simplywall.st/stocks/us/real-estate/nasdaq-glpi/gaming-and-leisure-properties/valuation
#  ($88.66)
# https://simplywall.st/stocks/us/real-estate/nasdaq-hst/host-hotels-resorts/valuation
#  ($71.12)
# https://simplywall.st/stocks/us/real-estate/nyse-bxp/boston-properties/valuation
#  ($95.4)
# https://simplywall.st/stocks/us/real-estate/nyse-amh/american-homes-4-rent/valuation
#  ($43.62)
# https://simplywall.st/stocks/us/real-estate/nyse-els/equity-lifestyle-properties/valuation
#  ($57.67)
# https://simplywall.st/stocks/us/real-estate/nyse-cpt/camden-property-trust/valuation
#  ($170.12)
# https://simplywall.st/stocks/us/real-estate/nasdaq-reg/regency-centers/valuation
#  ($95.82)
# https://simplywall.st/stocks/us/real-estate/nyse-rexr/rexford-industrial-realty/valuation
#  ($79.93)
# https://simplywall.st/stocks/us/real-estate/nasdaq-lamr/lamar-advertising/valuation
#  ($196.57)
# https://simplywall.st/stocks/us/real-estate/nyse-cube/cubesmart/valuation
#  ($66.21)
# https://simplywall.st/stocks/us/real-estate/nyse-lsi/life-storage/valuation
#  ($185.97)
# https://simplywall.st/stocks/us/real-estate/nyse-acc/american-campus-communities/valuation
#  ($79.99)
# https://simplywall.st/stocks/us/real-estate/nyse-stor/store-capital/valuation
#  ($73.75)
# https://simplywall.st/stocks/us/real-estate/nyse-frt/federal-realty-investment-trust/valuation
#  ($141.98)
# https://simplywall.st/stocks/us/real-estate/nasdaq-zg/zillow-group/valuation
#  ($37.52)
# https://simplywall.st/stocks/us/real-estate/nyse-nnn/national-retail-properties/valuation
#  ($79.47)
# https://simplywall.st/stocks/us/real-estate/nyse-cold/americold-realty-trust/valuation
#  ($50.05)
# https://simplywall.st/stocks/us/real-estate/nyse-hr/healthcare-realty-trust/valuation
#  ($46.67)
# https://simplywall.st/stocks/us/real-estate/nyse-ohi/omega-healthcare-investors/valuation
#  ($64.64)
# https://simplywall.st/stocks/us/real-estate/nyse-jll/jones-lang-lasalle/valuation
#  ($419.54)
# https://simplywall.st/stocks/us/real-estate/nyse-mpw/medical-properties-trust/valuation
#  ($28.62)
# https://simplywall.st/stocks/us/real-estate/nyse-egp/eastgroup-properties/valuation
#  ($203.65)
# https://simplywall.st/stocks/us/real-estate/nyse-fr/first-industrial-realty-trust/valuation
#  ($70.09)
# https://simplywall.st/stocks/us/real-estate/nyse-brx/brixmor-property-group/valuation
#  ($40.78)
# https://simplywall.st/stocks/us/real-estate/nyse-psb/ps-business-parks/valuation
#  ($226.67)
# https://simplywall.st/stocks/us/real-estate/nyse-adc/agree-realty/valuation
#  ($183.32)
# https://simplywall.st/stocks/us/real-estate/nyse-stag/stag-industrial/valuation
#  ($49.77)
# https://simplywall.st/stocks/us/real-estate/nyse-airc/apartment-income-reit/valuation
#  ($48.27)
# https://simplywall.st/stocks/us/real-estate/nyse-src/spirit-realty-capital/valuation
#  ($124.53)
# https://simplywall.st/stocks/us/real-estate/nyse-ryn/rayonier/valuation
#  ($44.71)
# https://simplywall.st/stocks/us/real-estate/nyse-krc/kilroy-realty/valuation
#  ($73.06)
# https://simplywall.st/stocks/us/real-estate/nyse-vno/vornado-realty-trust/valuation
#  ($51.05)
# https://simplywall.st/stocks/us/real-estate/nyse-nsa/national-storage-affiliates-trust/valuation
#  ($80.37)
# https://simplywall.st/stocks/us/real-estate/nyse-rhp/ryman-hospitality-properties/valuation
#  ($259.99)
# https://simplywall.st/stocks/us/real-estate/nyse-krg/kite-realty-group-trust/valuation
#  ($41.77)
# https://simplywall.st/stocks/us/real-estate/nyse-trno/terreno-realty/valuation
#  ($60.28)
# https://simplywall.st/stocks/us/real-estate/nyse-irt/independence-realty-trust/valuation
#  ($29.01)
# https://simplywall.st/stocks/us/real-estate/nasdaq-pch/potlatchdeltic/valuation
#  ($157.37)
# https://simplywall.st/stocks/us/real-estate/nyse-cuz/cousins-properties/valuation
#  ($53.71)
# https://simplywall.st/stocks/us/real-estate/nyse-aple/apple-hospitality-reit/valuation
#  ($53.45)
# https://simplywall.st/stocks/us/real-estate/nasdaq-peco/phillips-edison/valuation
#  ($52.08)
# https://simplywall.st/stocks/us/real-estate/nyse-doc/physicians-realty-trust/valuation
#  ($23.83)
# https://simplywall.st/stocks/us/real-estate/nyse-dei/douglas-emmett/valuation
#  ($27.43)
# https://simplywall.st/stocks/us/real-estate/nyse-hhc/howard-hughes/valuation
#  ($91.67)
# https://simplywall.st/stocks/us/real-estate/nyse-bnl/broadstone-net-lease/valuation
#  ($46.14)
# https://simplywall.st/stocks/us/real-estate/nyse-hiw/highwoods-properties/valuation
#  ($50.86)
# https://simplywall.st/stocks/us/real-estate/nyse-iipr/innovative-industrial-properties/valuation
#  ($237.67)
# https://simplywall.st/stocks/us/real-estate/nyse-eprt/essential-properties-realty-trust/valuation
#  ($67.77)
# https://simplywall.st/stocks/us/real-estate/nyse-ofc/corporate-office-properties-trust/valuation
#  ($43.03)
# https://simplywall.st/stocks/us/real-estate/nasdaq-sbra/sabra-health-care-reit/valuation
#  ($33.17)
# https://simplywall.st/stocks/us/real-estate/nyse-epr/epr-properties/valuation
#  ($113.82)
# https://simplywall.st/stocks/us/real-estate/nyse-lxp/lxp-industrial-trust/valuation
#  ($10.85)
# https://simplywall.st/stocks/us/real-estate/nyse-out/outfront-media/valuation
#  ($47.74)
# https://simplywall.st/stocks/us/real-estate/nyse-eqc/equity-commonwealth/valuation
#  ($6.67)
# https://simplywall.st/stocks/us/real-estate/nyse-mac/macerich/valuation
#  ($18.22)
# https://simplywall.st/stocks/us/real-estate/nyse-sitc/site-centers/valuation
#  ($27.19)
# https://simplywall.st/stocks/us/real-estate/nyse-pk/park-hotels-resorts/valuation
#  ($75.96)
# https://simplywall.st/stocks/us/real-estate/nyse-slg/sl-green-realty/valuation
#  ($66.11)
# https://simplywall.st/stocks/us/real-estate/nyse-cwk/cushman-wakefield/valuation
#  ($18.62)
# https://simplywall.st/stocks/us/real-estate/nyse-jbgs/jbg-smith-properties/valuation
#  ($12.99)
# https://simplywall.st/stocks/us/real-estate/nyse-nhi/national-health-investors/valuation
#  ($126.21)
# https://simplywall.st/stocks/us/real-estate/nyse-kw/kennedy-wilson-holdings/valuation
#  ($12.38)
# https://simplywall.st/stocks/us/real-estate/nyse-fcpt/four-corners-property-trust/valuation
#  ($46.25)
# https://simplywall.st/stocks/us/real-estate/nyse-dbrg/digitalbridge-group/valuation
#  ($32.49)
# https://simplywall.st/stocks/us/real-estate/nyse-sho/sunstone-hotel-investors/valuation
#  ($46.05)
# https://simplywall.st/stocks/us/real-estate/nyse-aat/american-assets-trust/valuation
#  ($36.82)
# https://simplywall.st/stocks/us/real-estate/nyse-joe/st-joe/valuation
#  ($18.51)
# https://simplywall.st/stocks/us/real-estate/nyse-skt/tanger-factory-outlet-centers/valuation
#  ($35)
# https://simplywall.st/stocks/us/real-estate/nyse-peb/pebblebrook-hotel-trust/valuation
#  ($88.5)
# https://simplywall.st/stocks/us/real-estate/nasdaq-roic/retail-opportunity-investments/valuation
#  ($18.58)
# https://simplywall.st/stocks/us/real-estate/nyse-safe/safehold/valuation
#  ($43.54)
# https://simplywall.st/stocks/us/real-estate/nyse-esrt/empire-state-realty-trust/valuation
#  ($8.06)
# https://simplywall.st/stocks/us/real-estate/nyse-ctre/caretrust-reit/valuation
#  ($40.86)
# https://simplywall.st/stocks/us/real-estate/nasdaq-expi/exp-world-holdings/valuation
#  ($90.61)
# https://simplywall.st/stocks/us/real-estate/nyse-rlj/rlj-lodging-trust/valuation
#  ($64.95)
# https://simplywall.st/stocks/us/real-estate/nyse-we/wework/valuation
#  ($11.97)
# https://simplywall.st/stocks/us/real-estate/nyse-drh/diamondrock-hospitality/valuation
#  ($36.17)
# https://simplywall.st/stocks/us/real-estate/nyse-ue/urban-edge-properties/valuation
#  ($36.9)
# https://simplywall.st/stocks/us/real-estate/nyse-xhr/xenia-hotels-resorts/valuation
#  ($60.97)
# https://simplywall.st/stocks/us/real-estate/nasdaq-unit/uniti-group/valuation
#  ($28.35)
# https://simplywall.st/stocks/us/real-estate/nyse-ivt/inventrust-properties/valuation
#  ($30.51)
# https://simplywall.st/stocks/us/real-estate/nyse-elme/elme-communities/valuation
#  ($23.16)
# https://simplywall.st/stocks/us/real-estate/nasdaq-nmrk/newmark-group/valuation
#  ($19.32)
# https://simplywall.st/stocks/us/real-estate/nyse-dea/easterly-government-properties/valuation
#  ($26.75)
# https://simplywall.st/stocks/us/real-estate/nyse-hpp/hudson-pacific-properties/valuation
#  ($10.27)
# https://simplywall.st/stocks/us/real-estate/nyse-apts/preferred-apartment-communities/valuation
#  ($14.64)
# https://simplywall.st/stocks/us/real-estate/nyse-ltc/ltc-properties/valuation
#  ($83.15)
# https://simplywall.st/stocks/us/real-estate/nyse-pgre/paramount-group/valuation
#  ($6.95)
# https://simplywall.st/stocks/us/real-estate/nyse-gty/getty-realty/valuation
#  ($56.54)
# https://simplywall.st/stocks/us/real-estate/nyse-vre/veris-residential/valuation
#  ($2.57)
# https://simplywall.st/stocks/us/real-estate/nyse-alex/alexander-baldwin/valuation
#  ($15.99)
# https://simplywall.st/stocks/us/real-estate/nyse-akr/acadia-realty-trust/valuation
#  ($24.28)
# https://simplywall.st/stocks/us/real-estate/nyse-mmi/marcus-millichap/valuation
#  ($46)
# https://simplywall.st/stocks/us/real-estate/nyse-bfs/saul-centers/valuation
#  ($59.38)
# https://simplywall.st/stocks/us/real-estate/nyse-gnl/global-net-lease/valuation
#  ($26.22)
# https://simplywall.st/stocks/us/real-estate/nyse-pdm/piedmont-office-realty-trust/valuation
#  ($22.86)
# https://simplywall.st/stocks/us/real-estate/nasdaq-svc/service-properties-trust/valuation
#  ($8.11)
# https://simplywall.st/stocks/us/real-estate/nyse-aiv/apartment-investment-and-management/valuation
#  ($28.64)
# https://simplywall.st/stocks/us/real-estate/nyse-alx/alexanders/valuation
#  ($189.71)
# https://simplywall.st/stocks/us/real-estate/nyse-nxrt/nexpoint-residential-trust/valuation
#  ($67.82)
# https://simplywall.st/stocks/us/real-estate/nasdaq-open/opendoor-technologies/valuation
# nan
# https://simplywall.st/stocks/us/real-estate/nyse-bdn/brandywine-realty-trust/valuation
#  ($16.26)
# https://simplywall.st/stocks/us/real-estate/nysemkt-brg/bluerock-residential-growth-reit/valuation
#  ($61.77)
# https://simplywall.st/stocks/us/real-estate/nyse-ahh/armada-hoffler-properties/valuation
#  ($16.6)
# https://simplywall.st/stocks/us/real-estate/nyse-comp/compass/valuation
#  ($10.38)
# https://simplywall.st/stocks/us/real-estate/nyse-csr/centerspace/valuation
#  ($108.05)
# https://simplywall.st/stocks/us/real-estate/nyse-ntst/netstreit/valuation
#  ($66.46)
# https://simplywall.st/stocks/us/real-estate/nyse-umh/umh-properties/valuation
#  ($30.88)
# https://simplywall.st/stocks/us/real-estate/nyse-inn/summit-hotel-properties/valuation
#  ($22.43)
# https://simplywall.st/stocks/us/real-estate/nyse-star/istar/valuation
#  ($11.21)
# https://simplywall.st/stocks/us/real-estate/nyse-rpt/rpt-realty/valuation
#  ($17.23)
# https://simplywall.st/stocks/us/real-estate/nyse-cbl/cbl-associates-properties/valuation
#  ($129.33)
# https://simplywall.st/stocks/us/real-estate/nyse-plym/plymouth-industrial-reit/valuation
#  ($32.64)
# https://simplywall.st/stocks/us/real-estate/nasdaq-rtl/necessity-retail-reit/valuation
#  ($14.87)
# https://simplywall.st/stocks/us/real-estate/nasdaq-rmr/rmr-group/valuation
#  ($56.89)
# https://simplywall.st/stocks/us/real-estate/nyse-chct/community-healthcare-trust/valuation
#  ($116.27)
# https://simplywall.st/stocks/us/real-estate/nyse-fpi/farmland-partners/valuation
#  ($16.9)
# https://simplywall.st/stocks/us/real-estate/nyse-hous/anywhere-real-estate/valuation
#  ($70.47)
# https://simplywall.st/stocks/us/real-estate/nasdaq-land/gladstone-land/valuation
#  ($20.78)
# https://simplywall.st/stocks/us/real-estate/nasdaq-opi/office-properties-income-trust/valuation
#  ($14.87)
# https://simplywall.st/stocks/us/real-estate/nasdaq-good/gladstone-commercial/valuation
#  ($32.48)
# https://simplywall.st/stocks/us/real-estate/nyse-uba/urstadt-biddle-properties/valuation
#  ($31.27)
# https://simplywall.st/stocks/us/real-estate/nyse-uht/universal-health-realty-income-trust/valuation
#  ($81.64)
# https://simplywall.st/stocks/us/real-estate/nyse-for/forestar-group/valuation
#  ($34.08)
# https://simplywall.st/stocks/us/real-estate/nyse-srg/seritage-growth-properties/valuation
# nan
# https://simplywall.st/stocks/us/real-estate/nyse-gmre/global-medical-reit/valuation
#  ($28.78)
# https://simplywall.st/stocks/us/real-estate/nyse-cldt/chatham-lodging-trust/valuation
#  ($47.75)
# https://simplywall.st/stocks/us/real-estate/nyse-nxdt/nexpoint-diversified-real-estate-trust/valuation
# nan
# https://simplywall.st/stocks/us/real-estate/nasdaq-indt/indus-realty-trust/valuation
#  ($55.06)
# https://simplywall.st/stocks/us/real-estate/nyse-rmax/re-max-holdings/valuation
#  ($32.85)
# https://simplywall.st/stocks/us/real-estate/nasdaq-frph/frp-holdings/valuation
#  ($36.66)
# https://simplywall.st/stocks/us/real-estate/nyse-onl/orion-office-reit/valuation
#  ($15.8)
# https://simplywall.st/stocks/us/real-estate/nyse-olp/one-liberty-properties/valuation
#  ($36.3)
# https://simplywall.st/stocks/us/real-estate/nyse-ctt/catchmark-timber-trust/valuation
#  ($13.81)
# https://simplywall.st/stocks/us/real-estate/nyse-trc/tejon-ranch/valuation
#  ($2.1)
# https://simplywall.st/stocks/us/real-estate/nyse-wsr/whitestone-reit/valuation
#  ($12.45)
# https://simplywall.st/stocks/us/real-estate/nasdaq-rdfn/redfin/valuation
#  ($14.81)
# https://simplywall.st/stocks/us/real-estate/nyse-ht/hersha-hospitality-trust/valuation
#  ($41.41)
# https://simplywall.st/stocks/us/real-estate/nyse-brt/brt-apartments/valuation
#  ($40.1)
# https://simplywall.st/stocks/us/real-estate/nyse-cio/city-office-reit/valuation
#  ($12.91)
# https://simplywall.st/stocks/us/retail/nasdaq-amzn/amazoncom/valuation
#  ($244.96)
# https://simplywall.st/stocks/us/retail/nyse-hd/home-depot/valuation
#  ($321.48)
# https://simplywall.st/stocks/us/retail/nyse-baba/alibaba-group-holding/valuation
#  ($148.11)
# https://simplywall.st/stocks/us/retail/nyse-low/lowes-companies/valuation
#  ($299.91)
# https://simplywall.st/stocks/us/retail/nyse-tjx/tjx-companies/valuation
#  ($62.76)
# https://simplywall.st/stocks/us/retail/nasdaq-pdd/pinduoduo/valuation
#  ($83.08)
# https://simplywall.st/stocks/us/retail/nyse-tgt/target/valuation
#  ($250.26)
# https://simplywall.st/stocks/us/retail/nasdaq-jd/jdcom/valuation
#  ($94.05)
# https://simplywall.st/stocks/us/retail/nyse-dg/dollar-general/valuation
#  ($278.57)
# https://simplywall.st/stocks/us/retail/nasdaq-orly/oreilly-automotive/valuation
#  ($736.16)
# https://simplywall.st/stocks/us/retail/nasdaq-meli/mercadolibre/valuation
#  ($1013.1)
# https://simplywall.st/stocks/us/retail/nyse-azo/autozone/valuation
#  ($2714.92)
# https://simplywall.st/stocks/us/retail/nasdaq-dltr/dollar-tree/valuation
#  ($126.64)
# https://simplywall.st/stocks/us/retail/nyse-cpng/coupang/valuation
#  ($27.6)
# https://simplywall.st/stocks/us/retail/nasdaq-rost/ross-stores/valuation
#  ($140.94)
# https://simplywall.st/stocks/us/retail/nasdaq-ebay/ebay/valuation
#  ($90.49)
# https://simplywall.st/stocks/us/retail/nyse-gpc/genuine-parts/valuation
#  ($143.12)
# https://simplywall.st/stocks/us/retail/nyse-dash/doordash/valuation
#  ($38.97)
# https://simplywall.st/stocks/us/retail/nasdaq-tsco/tractor-supply/valuation
#  ($209.36)
# https://simplywall.st/stocks/us/retail/nasdaq-ulta/ulta-beauty/valuation
#  ($469.31)
# https://simplywall.st/stocks/us/retail/nyse-chwy/chewy/valuation
#  ($46.95)
# https://simplywall.st/stocks/us/retail/nyse-bby/best-buy/valuation
#  ($154.13)
# https://simplywall.st/stocks/us/retail/nasdaq-etsy/etsy/valuation
#  ($208.74)
# https://simplywall.st/stocks/us/retail/nasdaq-lkq/lkq/valuation
#  ($74.08)
# https://simplywall.st/stocks/us/retail/nasdaq-pool/pool/valuation
#  ($315.43)
# https://simplywall.st/stocks/us/retail/nyse-kmx/carmax/valuation
#  ($133.42)
# https://simplywall.st/stocks/us/retail/nyse-aap/advance-auto-parts/valuation
#  ($265.81)
# https://simplywall.st/stocks/us/retail/nyse-burl/burlington-stores/valuation
#  ($21.36)
# https://simplywall.st/stocks/us/retail/nyse-wsm/williams-sonoma/valuation
#  ($258.51)
# https://simplywall.st/stocks/us/retail/nyse-pag/penske-automotive-group/valuation
#  ($136.23)
# https://simplywall.st/stocks/us/retail/nyse-fnd/floor-decor-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-dks/dicks-sporting-goods/valuation
#  ($154.86)
# https://simplywall.st/stocks/us/retail/nasdaq-five/five-below/valuation
#  ($141.89)
# https://simplywall.st/stocks/us/retail/nyse-bbwi/bath-body-works/valuation
#  ($18.92)
# https://simplywall.st/stocks/us/retail/nyse-gme/gamestop/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-rh/rh/valuation
#  ($590.99)
# https://simplywall.st/stocks/us/retail/nyse-lad/lithia-motors/valuation
#  ($494.8)
# https://simplywall.st/stocks/us/retail/nyse-musa/murphy-usa/valuation
#  ($326.94)
# https://simplywall.st/stocks/us/retail/nyse-dds/dillards/valuation
#  ($47.3)
# https://simplywall.st/stocks/us/retail/nyse-an/autonation/valuation
#  ($204.91)
# https://simplywall.st/stocks/us/retail/nyse-m/macys/valuation
#  ($27.1)
# https://simplywall.st/stocks/us/retail/nyse-vips/vipshop-holdings/valuation
#  ($27.31)
# https://simplywall.st/stocks/us/retail/nyse-gps/gap/valuation
#  ($89.3)
# https://simplywall.st/stocks/us/retail/nyse-w/wayfair/valuation
#  ($168.51)
# https://simplywall.st/stocks/us/retail/nyse-abg/asbury-automotive-group/valuation
#  ($398.93)
# https://simplywall.st/stocks/us/retail/nyse-ftch/farfetch/valuation
#  ($17.72)
# https://simplywall.st/stocks/us/retail/nasdaq-glbe/global-e-online/valuation
#  ($22.9)
# https://simplywall.st/stocks/us/retail/nyse-kss/kohls/valuation
#  ($59.9)
# https://simplywall.st/stocks/us/retail/nyse-kss/kohls/valuation
#  ($59.9)
# https://simplywall.st/stocks/us/retail/nasdaq-glbe/global-e-online/valuation
#  ($22.9)
# https://simplywall.st/stocks/us/retail/nyse-ftch/farfetch/valuation
#  ($17.72)
# https://simplywall.st/stocks/us/retail/nyse-jwn/nordstrom/valuation
#  ($28.18)
# https://simplywall.st/stocks/us/retail/nasdaq-eye/national-vision-holdings/valuation
#  ($30.92)
# https://simplywall.st/stocks/us/retail/nyse-fl/foot-locker/valuation
#  ($28.68)
# https://simplywall.st/stocks/us/retail/nyse-sig/signet-jewelers/valuation
#  ($70.98)
# https://simplywall.st/stocks/us/retail/nasdaq-woof/petco-health-and-wellness/valuation
#  ($1.3)
# https://simplywall.st/stocks/us/retail/nasdaq-lesl/leslies/valuation
#  ($21.48)
# https://simplywall.st/stocks/us/retail/nyse-gpi/group-1-automotive/valuation
#  ($272.21)
# https://simplywall.st/stocks/us/retail/nyse-cwh/camping-world-holdings/valuation
#  ($41.68)
# https://simplywall.st/stocks/us/retail/nasdaq-urbn/urban-outfitters/valuation
#  ($90.16)
# https://simplywall.st/stocks/us/retail/nyse-aeo/american-eagle-outfitters/valuation
#  ($23.84)
# https://simplywall.st/stocks/us/retail/nyse-mnso/miniso-group-holding/valuation
#  ($17.42)
# https://simplywall.st/stocks/us/retail/nasdaq-xmtr/xometry/valuation
#  ($24.94)
# https://simplywall.st/stocks/us/retail/nasdaq-odp/odp/valuation
#  ($6.9)
# https://simplywall.st/stocks/us/retail/nyse-bke/buckle/valuation
#  ($49.84)
# https://simplywall.st/stocks/us/retail/nyse-sah/sonic-automotive/valuation
#  ($16.76)
# https://simplywall.st/stocks/us/retail/nyse-ssu/signa-sports-united/valuation
#  ($13.28)
# https://simplywall.st/stocks/us/retail/nyse-boot/boot-barn-holdings/valuation
#  ($53.08)
# https://simplywall.st/stocks/us/retail/nyse-rvlv/revolve-group/valuation
#  ($31.3)
# https://simplywall.st/stocks/us/retail/nasdaq-evgo/evgo/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-wrby/warby-parker/valuation
#  ($9.52)
# https://simplywall.st/stocks/us/retail/nyse-cvna/carvana/valuation
#  ($88.04)
# https://simplywall.st/stocks/us/retail/nasdaq-seat/vivid-seats/valuation
#  ($22.77)
# https://simplywall.st/stocks/us/retail/nasdaq-mnro/monro/valuation
#  ($83.69)
# https://simplywall.st/stocks/us/retail/nasdaq-posh/poshmark/valuation
#  ($37.53)
# https://simplywall.st/stocks/us/retail/nyse-sbh/sally-beauty-holdings/valuation
#  ($24.19)
# https://simplywall.st/stocks/us/retail/nyse-fvrr/fiverr-international/valuation
#  ($33.28)
# https://simplywall.st/stocks/us/retail/nasdaq-rcii/rent-a-center/valuation
#  ($46.02)
# https://simplywall.st/stocks/us/retail/nasdaq-arhs/arhaus/valuation
#  ($1.84)
# https://simplywall.st/stocks/us/retail/nasdaq-ostk/overstockcom/valuation
#  ($42.75)
# https://simplywall.st/stocks/us/retail/nasdaq-arko/arko/valuation
#  ($10.35)
# https://simplywall.st/stocks/us/retail/nasdaq-frg/franchise-group/valuation
#  ($234.52)
# https://simplywall.st/stocks/us/retail/nyse-ges/guess/valuation
#  ($28.84)
# https://simplywall.st/stocks/us/retail/nyse-dbi/designer-brands/valuation
#  ($22.11)
# https://simplywall.st/stocks/us/retail/nyse-cal/caleres/valuation
#  ($70.8)
# https://simplywall.st/stocks/us/retail/nyse-anf/abercrombie-fitch/valuation
#  ($30.44)
# https://simplywall.st/stocks/us/retail/nyse-myte/myt-netherlands-parent-bv/valuation
#  ($7.33)
# https://simplywall.st/stocks/us/retail/nasdaq-dada/dada-nexus/valuation
#  ($15.47)
# https://simplywall.st/stocks/us/retail/nasdaq-wina/winmark/valuation
#  ($258.51)
# https://simplywall.st/stocks/us/retail/nyse-chs/chicos-fas/valuation
#  ($20.53)
# https://simplywall.st/stocks/us/retail/nasdaq-hibb/hibbett/valuation
#  ($107.75)
# https://simplywall.st/stocks/us/retail/nasdaq-ta/travelcenters-of-america/valuation
#  ($0.73)
# https://simplywall.st/stocks/us/retail/nasdaq-qrte.a/qurate-retail/valuation
#  ($0.53)
# https://simplywall.st/stocks/us/retail/nyse-hzo/marinemax/valuation
#  ($116.57)
# https://simplywall.st/stocks/us/retail/nasdaq-brlt/brilliant-earth-group/valuation
#  ($15.35)
# https://simplywall.st/stocks/us/retail/nyse-allg/allego/valuation
#  ($4.81)
# https://simplywall.st/stocks/us/retail/nasdaq-scvl/shoe-carnival/valuation
#  ($24.26)
# https://simplywall.st/stocks/us/retail/nasdaq-snbr/sleep-number/valuation
#  ($66.03)
# https://simplywall.st/stocks/us/retail/nasdaq-lqdt/liquidity-services/valuation
#  ($37.1)
# https://simplywall.st/stocks/us/retail/nasdaq-negg/newegg-commerce/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-gco/genesco/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-flws/1-800-flowerscom/valuation
#  ($15.63)
# https://simplywall.st/stocks/us/retail/nyse-big/big-lots/valuation
#  ($28.21)
# https://simplywall.st/stocks/us/retail/nasdaq-onew/onewater-marine/valuation
#  ($131.79)
# https://simplywall.st/stocks/us/retail/nyse-hvt/haverty-furniture-companies/valuation
#  ($49.46)
# https://simplywall.st/stocks/us/retail/nasdaq-fnko/funko/valuation
#  ($24.98)
# https://simplywall.st/stocks/us/retail/nasdaq-wish/contextlogic/valuation
#  ($8.25)
# https://simplywall.st/stocks/us/retail/nasdaq-plce/childrens-place/valuation
#  ($36.87)
# https://simplywall.st/stocks/us/retail/nasdaq-sfix/stitch-fix/valuation
#  ($5.49)
# https://simplywall.st/stocks/us/retail/nyse-curv/torrid-holdings/valuation
#  ($20.79)
# https://simplywall.st/stocks/us/retail/nasdaq-zumz/zumiez/valuation
#  ($5.85)
# https://simplywall.st/stocks/us/retail/nasdaq-crmt/americas-car-mart/valuation
#  ($0.1)
# https://simplywall.st/stocks/us/retail/nasdaq-pets/petmed-express/valuation
#  ($35.16)
# https://simplywall.st/stocks/us/retail/nyse-jmia/jumia-technologies/valuation
#  ($66.9)
# https://simplywall.st/stocks/us/retail/nasdaq-dxlg/destination-xl-group/valuation
#  ($17.09)
# https://simplywall.st/stocks/us/retail/nyse-rere/atrenew/valuation
#  ($4.92)
# https://simplywall.st/stocks/us/retail/nasdaq-spwh/sportsmans-warehouse-holdings/valuation
#  ($11.75)
# https://simplywall.st/stocks/us/retail/nasdaq-le/lands-end/valuation
#  ($8.41)
# https://simplywall.st/stocks/us/retail/nyse-cang/cango/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-aan/aarons/valuation
#  ($7.01)
# https://simplywall.st/stocks/us/retail/nasdaq-bbby/bed-bath-beyond/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-quot/quotient-technology/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-grwg/growgeneration/valuation
#  ($21.55)
# https://simplywall.st/stocks/us/retail/nyse-bark/bark/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-grpn/groupon/valuation
#  ($22.42)
# https://simplywall.st/stocks/us/retail/nyse-tlys/tillys/valuation
#  ($18.79)
# https://simplywall.st/stocks/us/retail/nasdaq-dlth/duluth-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-czoo/cazoo-group/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-bgfv/big-5-sporting-goods/valuation
#  ($15.85)
# https://simplywall.st/stocks/us/retail/nasdaq-bwmx/betterware-de-mexicopi-de/valuation
#  ($7.35)
# https://simplywall.st/stocks/us/retail/nyse-bbw/build-a-bear-workshop/valuation
#  ($3.34)
# https://simplywall.st/stocks/us/retail/nasdaq-prts/carpartscom/valuation
#  ($25.66)
# https://simplywall.st/stocks/us/retail/nasdaq-gct/gigacloud-technology/valuation
#  ($1.08)
# https://simplywall.st/stocks/us/retail/nyse-jill/jjill/valuation
#  ($92.67)
# https://simplywall.st/stocks/us/retail/nasdaq-weys/weyco-group/valuation
#  ($17.01)
# https://simplywall.st/stocks/us/retail/nasdaq-joan/joann/valuation
#  ($67.74)
# https://simplywall.st/stocks/us/retail/nyse-tcs/container-store-group/valuation
#  ($3.41)
# https://simplywall.st/stocks/us/retail/nyse-cato/cato/valuation
#  ($10.78)
# https://simplywall.st/stocks/us/retail/nyse-grov/grove-collaborative-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-heps/d-market-elektronik-hizmetler-ve-ticaret/valuation
#  ($4.65)
# https://simplywall.st/stocks/us/retail/nasdaq-conn/conns/valuation
#  ($0.81)
# https://simplywall.st/stocks/us/retail/nasdaq-dibs/1stdibscom/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-ll/ll-flooring-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-bzun/baozun/valuation
#  ($19.18)
# https://simplywall.st/stocks/us/retail/nasdaq-lvlu/lulus-fashion-lounge-holdings/valuation
#  ($39.27)
# https://simplywall.st/stocks/us/retail/nyse-aka/aka-brands-holding/valuation
#  ($2.46)
# https://simplywall.st/stocks/us/retail/nasdaq-em/smart-share-global/valuation
#  ($9.9)
# https://simplywall.st/stocks/us/retail/nasdaq-ttsh/tile-shop-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-ctrn/citi-trends/valuation
#  ($15.12)
# https://simplywall.st/stocks/us/retail/nyse-bned/barnes-noble-education/valuation
#  ($0.46)
# https://simplywall.st/stocks/us/retail/nasdaq-rmbl/rumbleon/valuation
#  ($35.21)
# https://simplywall.st/stocks/us/retail/nasdaq-yj/yunji/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-lazy/lazydays-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-real/realreal/valuation
#  ($27.92)
# https://simplywall.st/stocks/us/retail/nyse-vlta/volta/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-vrm/vroom/valuation
# nan
# https://simplywall.st/stocks/us/retail/nysemkt-ela/envela/valuation
#  ($24.77)
# https://simplywall.st/stocks/us/retail/nasdaq-uxin/uxin/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-litb/lightinthebox-holding/valuation
# nan
# https://simplywall.st/stocks/us/retail/nysemkt-dit/amcon-distributing/valuation
#  ($638.03)
# https://simplywall.st/stocks/us/retail/nasdaq-rent/rent-the-runway/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-prch/porch-group/valuation
#  ($2.8)
# https://simplywall.st/stocks/us/retail/nyse-prty/party-city-holdco/valuation
# nan
# https://simplywall.st/stocks/us/retail/nysemkt-bgi/birks-group/valuation
#  ($48.16)
# https://simplywall.st/stocks/us/retail/nasdaq-kxin/kaixin-auto-holdings/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-hour/hour-loop/valuation
# nan
# https://simplywall.st/stocks/us/retail/nyse-expr/express/valuation
# nan
# https://simplywall.st/stocks/us/retail/nasdaq-tdup/thredup/valuation
# nan
# https://simplywall.st/stocks/us/semiconductors/nasdaq-nvda/nvidia/valuation
#  ($157.62)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-avgo/broadcom/valuation
#  ($544.88)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-txn/texas-instruments/valuation
#  ($180.33)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-qcom/qualcomm/valuation
#  ($170.01)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-intc/intel/valuation
#  ($21.72)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-amd/advanced-micro-devices/valuation
#  ($126.95)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-amat/applied-materials/valuation
#  ($123.3)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-adi/analog-devices/valuation
#  ($178.94)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-lrcx/lam-research/valuation
#  ($704.81)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-mu/micron-technology/valuation
#  ($38.26)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-klac/kla/valuation
#  ($439.43)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-nxpi/nxp-semiconductors/valuation
#  ($226.6)
# https://simplywall.st/stocks/us/semiconductors/nasdaq-mchp/microchip-technology/valuation
#  ($80.93)
# ...
#  ($59.57)
# https://simplywall.st/stocks/us/transportation/nyse-fdx/fedex/valuation
#  ($353.9)
# https://simplywall.st/stocks/us/transportation/nasdaq-odfl/old-dominion-freight-line/valuation
#  ($215.37)
# https://simplywall.st/stocks/us/transportation/nyse-luv/southwest-airlines/valuation
#  ($54.67)
# https://simplywall.st/stocks/us/transportation/nyse-dal/delta-air-lines/valuation
#  ($40.14)
# https://simplywall.st/stocks/us/transportation/nasdaq-jbht/jb-hunt-transport-services/valuation
#  ($170.58)
# https://simplywall.st/stocks/us/transportation/nasdaq-expd/expeditors-international-of-washington/valuation
#  ($117.26)
# https://simplywall.st/stocks/us/transportation/nyse-zto/zto-express-cayman/valuation
#  ($22.75)
# https://simplywall.st/stocks/us/transportation/nasdaq-ual/united-airlines-holdings/valuation
#  ($20.07)
# https://simplywall.st/stocks/us/transportation/nasdaq-chrw/ch-robinson-worldwide/valuation
#  ($122.99)
# https://simplywall.st/stocks/us/transportation/nasdaq-grab/grab-holdings/valuation
#  ($22.57)
# https://simplywall.st/stocks/us/transportation/nasdaq-uhal/amerco/valuation
#  ($1.81)
# https://simplywall.st/stocks/us/transportation/nasdaq-aal/american-airlines-group/valuation
#  ($40.19)
# https://simplywall.st/stocks/us/transportation/nasdaq-car/avis-budget-group/valuation
#  ($580.05)
# https://simplywall.st/stocks/us/transportation/nyse-knx/knight-swift-transportation-holdings/valuation
#  ($34)
# https://simplywall.st/stocks/us/transportation/nyse-ymm/full-truck-alliance/valuation
#  ($29.36)
# https://simplywall.st/stocks/us/transportation/nasdaq-saia/saia/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-lstr/landstar-system/valuation
#  ($120.84)
# https://simplywall.st/stocks/us/transportation/nasdaq-htz/hertz-global-holdings/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nyse-alk/alaska-air-group/valuation
#  ($3.1)
# https://simplywall.st/stocks/us/transportation/nyse-gxo/gxo-logistics/valuation
#  ($38.96)
# https://simplywall.st/stocks/us/transportation/nasdaq-lyft/lyft/valuation
#  ($53.99)
# https://simplywall.st/stocks/us/transportation/nyse-xpo/xpo-logistics/valuation
#  ($77.23)
# https://simplywall.st/stocks/us/transportation/nyse-r/ryder-system/valuation
#  ($43.37)
# https://simplywall.st/stocks/us/transportation/nyse-sndr/schneider-national/valuation
#  ($53.87)
# https://simplywall.st/stocks/us/transportation/nyse-atco/atlas/valuation
#  ($46.51)
# https://simplywall.st/stocks/us/transportation/nyse-kex/kirby/valuation
#  ($111.55)
# https://simplywall.st/stocks/us/transportation/nyse-zim/zim-integrated-shipping-services/valuation
#  ($126.3)
# https://simplywall.st/stocks/us/transportation/nasdaq-fwrd/forward-air/valuation
#  ($163.4)
# https://simplywall.st/stocks/us/transportation/nyse-cpa/copa-holdings/valuation
#  ($44.95)
# https://simplywall.st/stocks/us/transportation/nasdaq-ulcc/frontier-group-holdings/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-aaww/atlas-air-worldwide-holdings/valuation
#  ($236.83)
# https://simplywall.st/stocks/us/transportation/nyse-matx/matson/valuation
#  ($120.31)
# https://simplywall.st/stocks/us/transportation/nyse-joby/joby-aviation/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-hubg/hub-group/valuation
#  ($124.01)
# https://simplywall.st/stocks/us/transportation/nasdaq-jblu/jetblue-airways/valuation
#  ($13.28)
# https://simplywall.st/stocks/us/transportation/nasdaq-wern/werner-enterprises/valuation
#  ($295.83)
# https://simplywall.st/stocks/us/transportation/nyse-save/spirit-airlines/valuation
#  ($109.16)
# https://simplywall.st/stocks/us/transportation/nasdaq-sblk/star-bulk-carriers/valuation
#  ($46.74)
# https://simplywall.st/stocks/us/transportation/nasdaq-atsg/air-transport-services-group/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-arcb/arcbest/valuation
#  ($131.03)
# https://simplywall.st/stocks/us/transportation/nyse-rxo/rxo/valuation
#  ($27.56)
# https://simplywall.st/stocks/us/transportation/nasdaq-gogl/golden-ocean-group/valuation
#  ($22.08)
# https://simplywall.st/stocks/us/transportation/nasdaq-mrtn/marten-transport/valuation
#  ($13.43)
# https://simplywall.st/stocks/us/transportation/nasdaq-algt/allegiant-travel/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nyse-caap/corporacion-america-airports/valuation
#  ($99.26)
# https://simplywall.st/stocks/us/transportation/nasdaq-sncy/sun-country-airlines-holdings/valuation
#  ($28.89)
# https://simplywall.st/stocks/us/transportation/nyse-dac/danaos/valuation
#  ($1072.44)
# https://simplywall.st/stocks/us/transportation/nasdaq-htld/heartland-express/valuation
#  ($135.37)
# https://simplywall.st/stocks/us/transportation/nyse-cmre/costamare/valuation
#  ($38.05)
# https://simplywall.st/stocks/us/transportation/nasdaq-ulh/universal-logistics-holdings/valuation
#  ($18.58)
# https://simplywall.st/stocks/us/transportation/nasdaq-skyw/skywest/valuation
#  ($3.07)
# https://simplywall.st/stocks/us/transportation/nasdaq-ha/hawaiian-holdings/valuation
#  ($14.29)
# https://simplywall.st/stocks/us/transportation/nasdaq-egle/eagle-bulk-shipping/valuation
#  ($165.29)
# https://simplywall.st/stocks/us/transportation/nyse-gsl/global-ship-lease/valuation
#  ($88.08)
# https://simplywall.st/stocks/us/transportation/nyse-gnk/genco-shipping-trading/valuation
#  ($61.13)
# https://simplywall.st/stocks/us/transportation/nasdaq-ptsi/pam-transportation-services/valuation
#  ($179.44)
# https://simplywall.st/stocks/us/transportation/nasdaq-tsp/tusimple-holdings/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-cvlg/covenant-logistics-group/valuation
#  ($72.28)
# https://simplywall.st/stocks/us/transportation/nasdaq-grin/grindrod-shipping-holdings/valuation
#  ($120.05)
# https://simplywall.st/stocks/us/transportation/nyse-up/wheels-up-experience/valuation
#  ($23.27)
# https://simplywall.st/stocks/us/transportation/nasdaq-dske/daseke/valuation
#  ($12.53)
# https://simplywall.st/stocks/us/transportation/nyse-neti/eneti/valuation
#  ($80.99)
# https://simplywall.st/stocks/us/transportation/nyse-sb/safe-bulkers/valuation
#  ($16.14)
# https://simplywall.st/stocks/us/transportation/nyse-dsx/diana-shipping/valuation
#  ($10.23)
# https://simplywall.st/stocks/us/transportation/nasdaq-blde/blade-air-mobility/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nysemkt-rlgt/radiant-logistics/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-usak/usa-truck/valuation
#  ($42.41)
# https://simplywall.st/stocks/us/transportation/nasdaq-fip/ftai-infrastructure/valuation
#  ($2.18)
# https://simplywall.st/stocks/us/transportation/nasdaq-panl/pangaea-logistics-solutions/valuation
#  ($4.57)
# https://simplywall.st/stocks/us/transportation/nysemkt-skyh/sky-harbour-group/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-yell/yellow/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-esea/euroseas/valuation
#  ($17.76)
# https://simplywall.st/stocks/us/transportation/nyse-brds/bird-global/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-ctrm/castor-maritime/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nyse-usx/us-xpress-enterprises/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-ship/seanergy-maritime-holdings/valuation
#  ($0.38)
# https://simplywall.st/stocks/us/transportation/nasdaq-glg/td-holdings/valuation
#  ($0.72)
# https://simplywall.st/stocks/us/transportation/nasdaq-swvl/swvl-holdings/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-airt/air-t/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-atxg/addentax-group/valuation
#  ($2.83)
# https://simplywall.st/stocks/us/transportation/nasdaq-pxs/pyxis-tankers/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-mesa/mesa-air-group/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-sgly/singularity-future-technology/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nyse-nm/navios-maritime-holdings/valuation
#  ($292.02)
# https://simplywall.st/stocks/us/transportation/nyse-best/best/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-edry/eurodry/valuation
#  ($80.37)
# https://simplywall.st/stocks/us/transportation/nasdaq-ygmz/mingzhu-logistics-holdings/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-pati/patriot-transportation-holding/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-glbs/globus-maritime/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-usea/united-maritime/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-hyre/hyrecar/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-pshg/performance-shipping/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-hlbz/helbiz/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-ezgo/ezgo-technologies/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-op/oceanpal/valuation
# nan
# https://simplywall.st/stocks/us/transportation/nasdaq-frgt/freight-technologies/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nyse-nee/nextera-energy/valuation
#  ($38.19)
# https://simplywall.st/stocks/us/utilities/nyse-duk/duke-energy/valuation
#  ($77.49)
# https://simplywall.st/stocks/us/utilities/nyse-so/southern/valuation
#  ($121.78)
# https://simplywall.st/stocks/us/utilities/nyse-d/dominion-energy/valuation
#  ($112.71)
# https://simplywall.st/stocks/us/utilities/nyse-sre/sempra/valuation
#  ($123.59)
# https://simplywall.st/stocks/us/utilities/nasdaq-aep/american-electric-power/valuation
#  ($83.94)
# https://simplywall.st/stocks/us/utilities/nasdaq-exc/exelon/valuation
#  ($37.07)
# https://simplywall.st/stocks/us/utilities/nasdaq-xel/xcel-energy/valuation
#  ($265.05)
# https://simplywall.st/stocks/us/utilities/nyse-ed/consolidated-edison/valuation
#  ($81.02)
# https://simplywall.st/stocks/us/utilities/nasdaq-ceg/constellation-energy/valuation
#  ($359.42)
# https://simplywall.st/stocks/us/utilities/nyse-wec/wec-energy-group/valuation
#  ($63.13)
# https://simplywall.st/stocks/us/utilities/nyse-pcg/pge/valuation
#  ($4.29)
# https://simplywall.st/stocks/us/utilities/nyse-peg/public-service-enterprise-group/valuation
#  ($63.53)
# https://simplywall.st/stocks/us/utilities/nyse-es/eversource-energy/valuation
#  ($184.2)
# https://simplywall.st/stocks/us/utilities/nyse-awk/american-water-works/valuation
#  ($71.98)
# https://simplywall.st/stocks/us/utilities/nyse-eix/edison-international/valuation
#  ($103.76)
# https://simplywall.st/stocks/us/utilities/nyse-etr/entergy/valuation
#  ($108.69)
# https://simplywall.st/stocks/us/utilities/nyse-dte/dte-energy/valuation
#  ($97.18)
# https://simplywall.st/stocks/us/utilities/nyse-fe/firstenergy/valuation
#  ($23.83)
# https://simplywall.st/stocks/us/utilities/nyse-aee/ameren/valuation
#  ($62.92)
# https://simplywall.st/stocks/us/utilities/nyse-ppl/ppl/valuation
#  ($27.34)
# https://simplywall.st/stocks/us/utilities/nyse-aes/aes/valuation
#  ($34.56)
# https://simplywall.st/stocks/us/utilities/nyse-cnp/centerpoint-energy/valuation
#  ($18.64)
# https://simplywall.st/stocks/us/utilities/nyse-cms/cms-energy/valuation
#  ($49.88)
# https://simplywall.st/stocks/us/utilities/nyse-agr/avangrid/valuation
#  ($33.17)
# https://simplywall.st/stocks/us/utilities/nyse-ato/atmos-energy/valuation
#  ($80.21)
# https://simplywall.st/stocks/us/utilities/nyse-evrg/evergy/valuation
#  ($61.98)
# https://simplywall.st/stocks/us/utilities/nasdaq-lnt/alliant-energy/valuation
#  ($46.04)
# https://simplywall.st/stocks/us/utilities/nyse-wtrg/essential-utilities/valuation
#  ($30.49)
# https://simplywall.st/stocks/us/utilities/nyse-ni/nisource/valuation
#  ($79.08)
# https://simplywall.st/stocks/us/utilities/nyse-nrg/nrg-energy/valuation
#  ($112.13)
# https://simplywall.st/stocks/us/utilities/nyse-vst/vistra/valuation
#  ($107.54)
# https://simplywall.st/stocks/us/utilities/nyse-pnw/pinnacle-west-capital/valuation
#  ($205.45)
# https://simplywall.st/stocks/us/utilities/nyse-ugi/ugi/valuation
#  ($36.1)
# https://simplywall.st/stocks/us/utilities/nyse-oge/oge-energy/valuation
#  ($63.14)
# https://simplywall.st/stocks/us/utilities/nyse-cwen.a/clearway-energy/valuation
#  ($57.3)
# https://simplywall.st/stocks/us/utilities/nyse-nfg/national-fuel-gas/valuation
#  ($47.35)
# https://simplywall.st/stocks/us/utilities/nyse-ora/ormat-technologies/valuation
#  ($12.41)
# https://simplywall.st/stocks/us/utilities/nyse-ida/idacorp/valuation
#  ($80.06)
# https://simplywall.st/stocks/us/utilities/nyse-bipc/brookfield-infrastructure/valuation
#  ($46.76)
# https://simplywall.st/stocks/us/utilities/nyse-swx/southwest-gas-holdings/valuation
#  ($121.36)
# https://simplywall.st/stocks/us/utilities/nyse-ogs/one-gas/valuation
#  ($1079.12)
# https://simplywall.st/stocks/us/utilities/nyse-bkh/black-hills/valuation
#  ($62.59)
# https://simplywall.st/stocks/us/utilities/nyse-njr/new-jersey-resources/valuation
#  ($40.63)
# https://simplywall.st/stocks/us/utilities/nyse-he/hawaiian-electric-industries/valuation
#  ($37.45)
# https://simplywall.st/stocks/us/utilities/nyse-sji/south-jersey-industries/valuation
#  ($52.47)
# https://simplywall.st/stocks/us/utilities/nyse-por/portland-general-electric/valuation
#  ($31.12)
# https://simplywall.st/stocks/us/utilities/nyse-pnm/pnm-resources/valuation
#  ($36.61)
# https://simplywall.st/stocks/us/utilities/nyse-sr/spire/valuation
#  ($72.8)
# https://simplywall.st/stocks/us/utilities/nyse-awr/american-states-water/valuation
#  ($42.61)
# https://simplywall.st/stocks/us/utilities/nyse-ale/allete/valuation
#  ($60.47)
# https://simplywall.st/stocks/us/utilities/nyse-cwt/california-water-service-group/valuation
#  ($28.02)
# https://simplywall.st/stocks/us/utilities/nasdaq-ay/atlantica-sustainable-infrastructure/valuation
#  ($80.55)
# https://simplywall.st/stocks/us/utilities/nasdaq-nwe/northwestern/valuation
#  ($63.4)
# https://simplywall.st/stocks/us/utilities/nyse-ava/avista/valuation
#  ($40.14)
# https://simplywall.st/stocks/us/utilities/nyse-nova/sunnova-energy-international/valuation
#  ($20.31)
# https://simplywall.st/stocks/us/utilities/nasdaq-rnw/renew-energy-global/valuation
#  ($58.66)
# https://simplywall.st/stocks/us/utilities/nasdaq-mgee/mge-energy/valuation
#  ($40.71)
# https://simplywall.st/stocks/us/utilities/nasdaq-ottr/otter-tail/valuation
#  ($43.88)
# https://simplywall.st/stocks/us/utilities/nyse-sjw/sjw-group/valuation
#  ($34.72)
# https://simplywall.st/stocks/us/utilities/nyse-cpk/chesapeake-utilities/valuation
#  ($57.98)
# https://simplywall.st/stocks/us/utilities/nyse-nwn/northwest-natural-holding/valuation
#  ($48.15)
# https://simplywall.st/stocks/us/utilities/nasdaq-mntk/montauk-renewables/valuation
#  ($20.5)
# https://simplywall.st/stocks/us/utilities/nasdaq-msex/middlesex-water/valuation
#  ($30.46)
# https://simplywall.st/stocks/us/utilities/nyse-amps/altus-power/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nyse-utl/unitil/valuation
#  ($39.61)
# https://simplywall.st/stocks/us/utilities/nasdaq-yorw/york-water/valuation
#  ($19)
# https://simplywall.st/stocks/us/utilities/nasdaq-artn.a/artesian-resources/valuation
#  ($27.13)
# https://simplywall.st/stocks/us/utilities/nyse-azre/azure-power-global/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nyse-mic/macquarie-infrastructure-holdings/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nasdaq-gwrs/global-water-resources/valuation
#  ($84.14)
# https://simplywall.st/stocks/us/utilities/nasdaq-cwco/consolidated-water/valuation
#  ($44.95)
# https://simplywall.st/stocks/us/utilities/nasdaq-via/via-renewables/valuation
#  ($9.52)
# https://simplywall.st/stocks/us/utilities/nyse-gne/genie-energy/valuation
#  ($653.21)
# https://simplywall.st/stocks/us/utilities/nysemkt-ello/ellomay-capital/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nasdaq-rgco/rgc-resources/valuation
#  ($19.01)
# https://simplywall.st/stocks/us/utilities/nasdaq-pcyo/pure-cycle/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nasdaq-cdzi/cadiz/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nasdaq-wave/eco-wave-power-global/valuation
# nan
# https://simplywall.st/stocks/us/utilities/nasdaq-vvpr/vivopower-international/valuation
# nan

# %%
compare earnings transcript sentiments between companies in the same sector and see variances, then rank them
https://www.benzinga.com/quote/AAPL

compare analyst questions with responce

have a list of all operator/speaker names to delete

delete useless info

# %%
pd.set_option('display.max_rows', df_next.shape[0]+1)

df_next
# Out:
#                                                  href ticker  fair_value
# 0            /stocks/us/automobiles/nasdaq-tsla/tesla   TSLA         NaN
# 1       /stocks/us/automobiles/nyse-gm/general-motors     GM         NaN
# 2            /stocks/us/automobiles/nyse-f/ford-motor      F         NaN
# 3            /stocks/us/automobiles/nyse-race/ferrari   RACE         NaN
# 4              /stocks/us/automobiles/nyse-aptv/aptiv   APTV         NaN
# 5   /stocks/us/automobiles/nasdaq-rivn/rivian-auto...   RIVN         NaN
# 6      /stocks/us/automobiles/nasdaq-lcid/lucid-group   LCID         NaN
# 7            /stocks/us/automobiles/nasdaq-li/li-auto     LI         NaN
# 8                 /stocks/us/automobiles/nyse-nio/nio    NIO         NaN
# 9   /stocks/us/automobiles/nasdaq-psny/polestar-au...   PSNY         NaN
# 10         /stocks/us/automobiles/nyse-bwa/borgwarner    BWA         NaN
# 11               /stocks/us/automobiles/nyse-lea/lear    LEA         NaN
# 12            /stocks/us/automobiles/nyse-alv/autoliv    ALV         NaN
# 13    /stocks/us/automobiles/nyse-hog/harley-davidson    HOG         NaN
# 14          /stocks/us/automobiles/nasdaq-gntx/gentex   GNTX         NaN
# 15             /stocks/us/automobiles/nyse-xpev/xpeng   XPEV         NaN
# 16    /stocks/us/automobiles/nyse-tho/thor-industries    THO         NaN
# 17  /stocks/us/automobiles/nasdaq-foxf/fox-factory...   FOXF         NaN
# 18           /stocks/us/automobiles/nasdaq-vc/visteon     VC         NaN
# 19            /stocks/us/automobiles/nyse-adnt/adient   ADNT         NaN
# 20        /stocks/us/automobiles/nyse-qs/quantumscape     QS         NaN
# 21  /stocks/us/automobiles/nasdaq-gt/goodyear-tire...     GT         NaN
# 22  /stocks/us/automobiles/nasdaq-dorm/dorman-prod...   DORM         NaN
# 23    /stocks/us/automobiles/nyse-lcii/lci-industries   LCII         NaN
# 24  /stocks/us/automobiles/nasdaq-lazr/luminar-tec...   LAZR         NaN
# 25               /stocks/us/automobiles/nyse-dan/dana    DAN         NaN
# 26        /stocks/us/automobiles/nasdaq-thrm/gentherm   THRM         NaN
# 27             /stocks/us/automobiles/nyse-fsr/fisker    FSR         NaN
# 28  /stocks/us/automobiles/nyse-wgo/winnebago-indu...    WGO         NaN
# 29            /stocks/us/automobiles/nasdaq-xpel/xpel   XPEL         NaN
# 30            /stocks/us/automobiles/nyse-ten/tenneco    TEN         NaN
# 31    /stocks/us/automobiles/nyse-lvwr/livewire-group   LVWR         NaN
# 32  /stocks/us/automobiles/nasdaq-patk/patrick-ind...   PATK         NaN
# 33  /stocks/us/automobiles/nyse-mod/modine-manufac...    MOD         NaN
# 34  /stocks/us/automobiles/nyse-axl/american-axle-...    AXL         NaN
# 35     /stocks/us/automobiles/nasdaq-sldp/solid-power   SLDP         NaN
# 36  /stocks/us/automobiles/nyse-smp/standard-motor...    SMP         NaN
# 37           /stocks/us/automobiles/nasdaq-ggr/gogoro    GGR         NaN
# 38         /stocks/us/automobiles/nyse-sri/stoneridge    SRI         NaN
# 39   /stocks/us/automobiles/nasdaq-gtx/garrett-motion    GTX         NaN
# 40  /stocks/us/automobiles/nasdaq-wkhs/workhorse-g...   WKHS         NaN
# 41  /stocks/us/automobiles/nasdaq-ride/lordstown-m...   RIDE         NaN
# 42           /stocks/us/automobiles/nasdaq-goev/canoo   GOEV         NaN
# 43  /stocks/us/automobiles/nasdaq-mpaa/motorcar-pa...   MPAA         NaN
# 44            /stocks/us/automobiles/nyse-hlly/holley   HLLY         NaN
# 45  /stocks/us/automobiles/nasdaq-ffie/faraday-fut...   FFIE         NaN
# 46  /stocks/us/automobiles/nasdaq-kndi/kandi-techn...   KNDI         NaN
# 47         /stocks/us/automobiles/nasdaq-arvl/arrival   ARVL         NaN
# 48  /stocks/us/automobiles/nasdaq-niu/niu-technolo...    NIU         NaN
# 49  /stocks/us/automobiles/nasdaq-cenn/cenntro-ele...   CENN         NaN
# 50  /stocks/us/automobiles/nasdaq-muln/mullen-auto...   MULN         NaN
# 51  /stocks/us/automobiles/nasdaq-solo/electramecc...   SOLO         NaN
# 52  /stocks/us/automobiles/nyse-cps/cooper-standar...    CPS         NaN
# 53  /stocks/us/automobiles/nasdaq-caas/china-autom...   CAAS         NaN
# 54   /stocks/us/automobiles/nasdaq-ree/ree-automotive    REE         NaN
# 55  /stocks/us/automobiles/nasdaq-strt/strattec-se...   STRT         NaN
# 56            /stocks/us/automobiles/nyse-xl/xl-fleet     XL         NaN
# 57  /stocks/us/automobiles/nyse-sup/superior-indus...    SUP         NaN
# 58       /stocks/us/automobiles/nasdaq-sev/sono-group    SEV         NaN
# 59  /stocks/us/automobiles/nasdaq-amv/atlis-motor-...    AMV         NaN
# 60  /stocks/us/automobiles/nasdaq-sypr/sypris-solu...   SYPR         NaN
# 61  /stocks/us/automobiles/nasdaq-elms/electric-la...   ELMS         NaN
# 62  /stocks/us/automobiles/nasdaq-evtv/envirotech-...   EVTV         NaN
# 63    /stocks/us/automobiles/nasdaq-pev/phoenix-motor    PEV         NaN
# 64       /stocks/us/automobiles/nasdaq-wksp/worksport   WKSP         NaN
# 65          /stocks/us/automobiles/nasdaq-vlcn/volcon   VLCN         NaN
# 66         /stocks/us/automobiles/nasdaq-fuv/arcimoto    FUV         NaN
# 67            /stocks/us/automobiles/nasdaq-ayro/ayro   AYRO         NaN
# 68     /stocks/us/automobiles/nyse-hzn/horizon-global    HZN         NaN
# 69  /stocks/us/automobiles/nysemkt-ufab/unique-fab...   UFAB         NaN
# 0                                                 NaN    NaN   ($169.12)
# 0                                                 NaN    NaN    ($62.65)
# 0                                                 NaN    NaN    ($38.05)
# 0                                                 NaN    NaN    ($63.33)
# 0                                                 NaN    NaN   ($135.36)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN    ($56.87)
# 0                                                 NaN    NaN    ($40.82)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN   ($130.09)
# 0                                                 NaN    NaN   ($189.39)
# 0                                                 NaN    NaN   ($174.12)
# 0                                                 NaN    NaN    ($15.29)
# 0                                                 NaN    NaN    ($42.95)
# 0                                                 NaN    NaN    ($49.05)
# 0                                                 NaN    NaN    ($79.28)
# 0                                                 NaN    NaN    ($83.65)
# 0                                                 NaN    NaN   ($136.13)
# 0                                                 NaN    NaN    ($69.45)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN    ($21.32)
# 0                                                 NaN    NaN     ($1.91)
# 0                                                 NaN    NaN   ($135.05)
# 0                                                 NaN    NaN    ($31.33)
# 0                                                 NaN    NaN    ($32.95)
# 0                                                 NaN    NaN    ($73.32)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN    ($74.51)
# 0                                                 NaN    NaN     ($37.8)
# 0                                                 NaN    NaN    ($48.09)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN   ($114.22)
# 0                                                 NaN    NaN    ($40.22)
# 0                                                 NaN    NaN    ($23.68)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN    ($48.84)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN   ($147.71)
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN
# 0                                                 NaN    NaN         NaN

# %%
df_initial = pd.read_csv('hrefs/ref_'+"automobiles"+'.csv')
temp2 = df_fair_value.to_numpy()
df_initial.insert(loc=2, column="fair_value", value=temp2)
df_initial.to_csv('hrefs/ref_' + (sector) + '_copy.csv', index=False)

df_initial
# Out:
#                                                  href ticker  fair_value
# 0            /stocks/us/automobiles/nasdaq-tsla/tesla   TSLA   ($169.12)
# 1            /stocks/us/automobiles/nyse-f/ford-motor      F    ($38.05)
# 2       /stocks/us/automobiles/nyse-gm/general-motors     GM    ($62.65)
# 3            /stocks/us/automobiles/nyse-race/ferrari   RACE    ($63.33)
# 4   /stocks/us/automobiles/nasdaq-rivn/rivian-auto...   RIVN         NaN
# 5              /stocks/us/automobiles/nyse-aptv/aptiv   APTV   ($135.36)
# 6      /stocks/us/automobiles/nasdaq-lcid/lucid-group   LCID         NaN
# 7                 /stocks/us/automobiles/nyse-nio/nio    NIO    ($40.82)
# 8            /stocks/us/automobiles/nasdaq-li/li-auto     LI    ($56.87)
# 9   /stocks/us/automobiles/nasdaq-psny/polestar-au...   PSNY         NaN
# 10         /stocks/us/automobiles/nyse-bwa/borgwarner    BWA   ($130.09)
# 11               /stocks/us/automobiles/nyse-lea/lear    LEA   ($189.39)
# 12            /stocks/us/automobiles/nyse-alv/autoliv    ALV   ($174.12)
# 13    /stocks/us/automobiles/nyse-hog/harley-davidson    HOG    ($15.29)
# 14          /stocks/us/automobiles/nasdaq-gntx/gentex   GNTX    ($42.95)
# 15             /stocks/us/automobiles/nyse-xpev/xpeng   XPEV    ($49.05)
# 16    /stocks/us/automobiles/nyse-tho/thor-industries    THO    ($79.28)
# 17  /stocks/us/automobiles/nasdaq-foxf/fox-factory...   FOXF    ($83.65)
# 18           /stocks/us/automobiles/nasdaq-vc/visteon     VC   ($136.13)
# 19            /stocks/us/automobiles/nyse-adnt/adient   ADNT    ($69.45)
# 20        /stocks/us/automobiles/nyse-qs/quantumscape     QS         NaN
# 21  /stocks/us/automobiles/nasdaq-gt/goodyear-tire...     GT    ($21.32)
# 22  /stocks/us/automobiles/nasdaq-lazr/luminar-tec...   LAZR    ($31.33)
# 23  /stocks/us/automobiles/nasdaq-dorm/dorman-prod...   DORM     ($1.91)
# 24  /stocks/us/automobiles/nasdaq-lazr/luminar-tec...   LAZR    ($31.33)
# 25               /stocks/us/automobiles/nyse-dan/dana    DAN    ($32.95)
# 26        /stocks/us/automobiles/nasdaq-thrm/gentherm   THRM    ($73.32)
# 27             /stocks/us/automobiles/nyse-fsr/fisker    FSR         NaN
# 28  /stocks/us/automobiles/nyse-wgo/winnebago-indu...    WGO    ($74.51)
# 29            /stocks/us/automobiles/nasdaq-xpel/xpel   XPEL     ($37.8)
# 30            /stocks/us/automobiles/nyse-ten/tenneco    TEN    ($48.09)
# 31    /stocks/us/automobiles/nyse-lvwr/livewire-group   LVWR         NaN
# 32  /stocks/us/automobiles/nasdaq-patk/patrick-ind...   PATK   ($114.22)
# 33  /stocks/us/automobiles/nyse-mod/modine-manufac...    MOD    ($40.62)
# 34  /stocks/us/automobiles/nyse-axl/american-axle-...    AXL    ($23.68)
# 35     /stocks/us/automobiles/nasdaq-sldp/solid-power   SLDP         NaN
# 36  /stocks/us/automobiles/nyse-smp/standard-motor...    SMP    ($49.75)
# 37           /stocks/us/automobiles/nasdaq-ggr/gogoro    GGR         NaN
# 38         /stocks/us/automobiles/nyse-sri/stoneridge    SRI         NaN
# 39   /stocks/us/automobiles/nasdaq-gtx/garrett-motion    GTX   ($147.71)
# 40  /stocks/us/automobiles/nasdaq-wkhs/workhorse-g...   WKHS         NaN
# 41  /stocks/us/automobiles/nasdaq-ride/lordstown-m...   RIDE         NaN
# 42           /stocks/us/automobiles/nasdaq-goev/canoo   GOEV     ($6.28)
# 43  /stocks/us/automobiles/nasdaq-mpaa/motorcar-pa...   MPAA     ($2.65)
# 44            /stocks/us/automobiles/nyse-hlly/holley   HLLY      ($3.5)
# 45  /stocks/us/automobiles/nasdaq-ffie/faraday-fut...   FFIE         NaN
# 46  /stocks/us/automobiles/nasdaq-kndi/kandi-techn...   KNDI         NaN
# 47         /stocks/us/automobiles/nasdaq-arvl/arrival   ARVL         NaN
# 48  /stocks/us/automobiles/nasdaq-cenn/cenntro-ele...   CENN         NaN
# 49  /stocks/us/automobiles/nasdaq-niu/niu-technolo...    NIU         NaN
# 50  /stocks/us/automobiles/nasdaq-muln/mullen-auto...   MULN         NaN
# 51  /stocks/us/automobiles/nasdaq-solo/electramecc...   SOLO         NaN
# 52   /stocks/us/automobiles/nasdaq-ree/ree-automotive    REE         NaN
# 53  /stocks/us/automobiles/nyse-cps/cooper-standar...    CPS         NaN
# 54            /stocks/us/automobiles/nyse-xl/xl-fleet     XL         NaN
# 55  /stocks/us/automobiles/nasdaq-caas/china-autom...   CAAS         NaN
# 56  /stocks/us/automobiles/nasdaq-strt/strattec-se...   STRT         NaN
# 57  /stocks/us/automobiles/nyse-sup/superior-indus...    SUP         NaN
# 58       /stocks/us/automobiles/nasdaq-sev/sono-group    SEV         NaN
# 59  /stocks/us/automobiles/nasdaq-amv/atlis-motor-...    AMV         NaN
# 60  /stocks/us/automobiles/nasdaq-sypr/sypris-solu...   SYPR         NaN
# 61  /stocks/us/automobiles/nasdaq-elms/electric-la...   ELMS         NaN
# 62  /stocks/us/automobiles/nasdaq-evtv/envirotech-...   EVTV         NaN
# 63    /stocks/us/automobiles/nasdaq-pev/phoenix-motor    PEV         NaN
# 64          /stocks/us/automobiles/nasdaq-vlcn/volcon   VLCN         NaN
# 65       /stocks/us/automobiles/nasdaq-wksp/worksport   WKSP         NaN
# 66         /stocks/us/automobiles/nasdaq-fuv/arcimoto    FUV         NaN
# 67            /stocks/us/automobiles/nasdaq-ayro/ayro   AYRO         NaN
# 68     /stocks/us/automobiles/nyse-hzn/horizon-global    HZN         NaN
# 69  /stocks/us/automobiles/nysemkt-ufab/unique-fab...   UFAB         NaN

# %%
mytemps = pd.read_csv('hrefs/ref_'+'banks'+'.csv')

mytemps = mytemps.drop('fair_value', axis=1)
print(mytemps)
# Out:
#                                                   href ticker
# 0             /stocks/us/banks/nyse-jpm/jpmorgan-chase    JPM
# 1            /stocks/us/banks/nyse-bac/bank-of-america    BAC
# 2                /stocks/us/banks/nyse-wfc/wells-fargo    WFC
# 3                    /stocks/us/banks/nyse-c/citigroup      C
# 4                 /stocks/us/banks/nyse-usb/us-bancorp    USB
# ..                                                 ...    ...
# 163  /stocks/us/banks/nasdaq-nfbk/northfield-bancor...   NFBK
# 164  /stocks/us/banks/nyse-mcb/metropolitan-bank-ho...    MCB
# 165  /stocks/us/banks/nasdaq-fmbh/first-mid-bancshares   FMBH
# 166  /stocks/us/banks/nasdaq-pgc/peapack-gladstone-...    PGC
# 167  /stocks/us/banks/nasdaq-trst/trustco-bank-corp-ny   TRST
#
# [168 rows x 2 columns]

# %%
#Deletes all duplicates in dataframe
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

sectorlist = ["automobiles", "banks", "capital-goods", "commercial-services", 
"consumer-durables", "consumer-retailing", "consumer-services", "diversified-financials",
"energy", "food-beverage-tobacco", "healthcare", "household", "insurance", "materials", "media", 
"pharmaceuticals-biotech", "real-estate", "retail", "semiconductors", "software",
"tech", "telecom", "transportation", "utilities"]

for sector in sectorlist:
    df_initial = pd.read_csv('hrefs/ref_'+sector+'.csv')
    print(df_initial)
    df_initial = df_initial.drop_duplicates()
    df_initial.to_csv('hrefs/ref_'+sector+'.csv', index=False)
# Out:
#                                                  href ticker  fair_value
# 0            /stocks/us/automobiles/nasdaq-tsla/tesla   TSLA   ($169.12)
# 1            /stocks/us/automobiles/nyse-f/ford-motor      F    ($38.05)
# 2       /stocks/us/automobiles/nyse-gm/general-motors     GM    ($62.65)
# 3            /stocks/us/automobiles/nyse-race/ferrari   RACE    ($63.33)
# 4   /stocks/us/automobiles/nasdaq-rivn/rivian-auto...   RIVN         NaN
# ..                                                ...    ...         ...
# 64       /stocks/us/automobiles/nasdaq-wksp/worksport   WKSP         NaN
# 65         /stocks/us/automobiles/nasdaq-fuv/arcimoto    FUV         NaN
# 66            /stocks/us/automobiles/nasdaq-ayro/ayro   AYRO         NaN
# 67     /stocks/us/automobiles/nyse-hzn/horizon-global    HZN         NaN
# 68  /stocks/us/automobiles/nysemkt-ufab/unique-fab...   UFAB         NaN
#
# [69 rows x 3 columns]
#                                                   href ticker  fair_value
# 0             /stocks/us/banks/nyse-jpm/jpmorgan-chase    JPM   ($182.25)
# 1            /stocks/us/banks/nyse-bac/bank-of-america    BAC    ($53.44)
# 2                /stocks/us/banks/nyse-wfc/wells-fargo    WFC     ($71.4)
# 3                    /stocks/us/banks/nyse-c/citigroup      C    ($93.85)
# 4                 /stocks/us/banks/nyse-usb/us-bancorp    USB    ($84.21)
# ..                                                 ...    ...         ...
# 163  /stocks/us/banks/nasdaq-nfbk/northfield-bancor...   NFBK    ($14.51)
# 164  /stocks/us/banks/nyse-mcb/metropolitan-bank-ho...    MCB   ($180.19)
# 165  /stocks/us/banks/nasdaq-fmbh/first-mid-bancshares   FMBH    ($71.65)
# 166  /stocks/us/banks/nasdaq-pgc/peapack-gladstone-...    PGC   ($100.74)
# 167  /stocks/us/banks/nasdaq-trst/trustco-bank-corp-ny   TRST    ($52.99)
#
# [168 rows x 3 columns]
#                                                   href ticker  fair_value
# 0    /stocks/us/capital-goods/nasdaq-hon/honeywell-...    HON   ($249.71)
# 1    /stocks/us/capital-goods/nyse-rtx/raytheon-tec...    RTX    ($162.7)
# 2    /stocks/us/capital-goods/nyse-lmt/lockheed-martin    LMT   ($518.72)
# 3               /stocks/us/capital-goods/nyse-de/deere     DE   ($310.85)
# 4        /stocks/us/capital-goods/nyse-cat/caterpillar    CAT    ($197.5)
# ..                                                 ...    ...         ...
# 163        /stocks/us/capital-goods/nasdaq-envx/enovix   ENVX         NaN
# 164            /stocks/us/capital-goods/nyse-stem/stem   STEM    ($98.68)
# 165  /stocks/us/capital-goods/nasdaq-cswi/csw-indus...   CSWI   ($163.62)
# 166          /stocks/us/capital-goods/nyse-lnn/lindsay    LNN   ($148.48)
# 167      /stocks/us/capital-goods/nyse-alg/alamo-group    ALG   ($161.54)
#
# [168 rows x 3 columns]
#                                                   href ticker  fair_value
# 0    /stocks/us/commercial-services/nyse-wm/waste-m...     WM   ($152.14)
# 1    /stocks/us/commercial-services/nasdaq-ctas/cintas   CTAS   ($312.59)
# 2    /stocks/us/commercial-services/nyse-rsg/republ...    RSG   ($123.02)
# 3    /stocks/us/commercial-services/nyse-wcn/waste-...    WCN   ($107.46)
# 4    /stocks/us/commercial-services/nasdaq-csgp/cos...   CSGP    ($46.25)
# ..                                                 ...    ...         ...
# 135   /stocks/us/commercial-services/nasdaq-jan/janone    JAN         NaN
# 136  /stocks/us/commercial-services/nasdaq-sntg/sen...   SNTG         NaN
# 137  /stocks/us/commercial-services/nasdaq-staf/sta...   STAF         NaN
# 138     /stocks/us/commercial-services/nasdaq-qh/quhuo     QH         NaN
# 139  /stocks/us/commercial-services/nasdaq-areb/ame...   AREB         NaN
#
# [140 rows x 3 columns]
#                                                   href ticker  fair_value
# 0           /stocks/us/consumer-durables/nyse-nke/nike    NKE         NaN
# 1    /stocks/us/consumer-durables/nasdaq-lulu/lulul...   LULU   ($181.65)
# 2      /stocks/us/consumer-durables/nyse-dhi/dr-horton    DHI   ($207.41)
# 3         /stocks/us/consumer-durables/nyse-len/lennar    LEN     ($78.6)
# 4        /stocks/us/consumer-durables/nyse-grmn/garmin   GRMN   ($153.58)
# ..                                                 ...    ...         ...
# 126  /stocks/us/consumer-durables/nasdaq-evk/ever-g...    EVK         NaN
# 127  /stocks/us/consumer-durables/nasdaq-jxjt/jx-lu...   JXJT         NaN
# 128  /stocks/us/consumer-durables/nasdaq-ctib/yunho...   CTIB         NaN
# 129  /stocks/us/consumer-durables/nasdaq-nvfy/nova-...   NVFY         NaN
# 130  /stocks/us/consumer-durables/nasdaq-cnxa/conne...   CNXA         NaN
#
# [131 rows x 3 columns]
#                                                  href  ticker  fair_value
# 0      /stocks/us/consumer-retailing/nyse-wmt/walmart     WMT   ($172.12)
# 1   /stocks/us/consumer-retailing/nasdaq-cost/cost...    COST   ($534.36)
# 2        /stocks/us/consumer-retailing/nyse-syy/sysco     SYY   ($139.74)
# 3        /stocks/us/consumer-retailing/nyse-kr/kroger      KR    ($59.31)
# 4   /stocks/us/consumer-retailing/nasdaq-wba/walgr...     WBA    ($183.7)
# 5   /stocks/us/consumer-retailing/nyse-aci/alberts...     ACI    ($43.26)
# 6   /stocks/us/consumer-retailing/nyse-bj/bjs-whol...      BJ    ($162.5)
# 7   /stocks/us/consumer-retailing/nasdaq-casy/case...    CASY   ($357.85)
# 8   /stocks/us/consumer-retailing/nyse-pfgc/perfor...    PFGC   ($112.08)
# 9   /stocks/us/consumer-retailing/nyse-usfd/us-foo...    USFD     ($80.8)
# 10  /stocks/us/consumer-retailing/nasdaq-sfm/sprou...     SFM    ($42.28)
# 11  /stocks/us/consumer-retailing/nasdaq-go/grocer...      GO     ($0.22)
# 12  /stocks/us/consumer-retailing/nyse-unfi/united...    UNFI   ($190.86)
# 13  /stocks/us/consumer-retailing/nyse-wmk/weis-ma...     WMK    ($33.14)
# 14  /stocks/us/consumer-retailing/nasdaq-psmt/pric...    PSMT    ($20.96)
# 15  /stocks/us/consumer-retailing/nasdaq-imkt.a/in...  IMKT.A   ($266.72)
# 16  /stocks/us/consumer-retailing/nasdaq-chef/chef...    CHEF    ($74.47)
# 17  /stocks/us/consumer-retailing/nasdaq-ande/ande...    ANDE    ($17.06)
# 18  /stocks/us/consumer-retailing/nasdaq-sptn/spar...    SPTN    ($59.22)
# 19  /stocks/us/consumer-retailing/nyse-ddl/dingdon...     DDL    ($22.83)
# 20  /stocks/us/consumer-retailing/nasdaq-vlge.a/vi...  VLGE.A    ($33.03)
# 21    /stocks/us/consumer-retailing/nyse-rad/rite-aid     RAD   ($106.04)
# 22  /stocks/us/consumer-retailing/nyse-ngvc/natura...    NGVC     ($9.75)
# 23  /stocks/us/consumer-retailing/nasdaq-hffg/hf-f...    HFFG        ($0)
# 24  /stocks/us/consumer-retailing/nasdaq-wilc/g-wi...    WILC     ($7.99)
# 25  /stocks/us/consumer-retailing/nyse-aprn/blue-a...    APRN         NaN
# 26  /stocks/us/consumer-retailing/nasdaq-mdvl/meda...    MDVL         NaN
# 27  /stocks/us/consumer-retailing/nasdaq-btb/bit-b...     BTB         NaN
# 28  /stocks/us/consumer-retailing/nasdaq-rebn/rebo...    REBN    ($35.62)
# 29  /stocks/us/consumer-retailing/nasdaq-mf/missfresh      MF         NaN
# 30  /stocks/us/consumer-retailing/nasdaq-cjjd/chin...    CJJD         NaN
#                                                   href ticker   fair_value
# 0      /stocks/us/consumer-services/nyse-mcd/mcdonalds    MCD     ($244.9)
# 1    /stocks/us/consumer-services/nasdaq-sbux/starb...   SBUX     ($97.75)
# 2    /stocks/us/consumer-services/nasdaq-bkng/booki...   BKNG   ($3275.68)
# 3      /stocks/us/consumer-services/nasdaq-abnb/airbnb   ABNB     ($198.8)
# 4    /stocks/us/consumer-services/nasdaq-mar/marrio...    MAR    ($204.33)
# ..                                                 ...    ...          ...
# 163  /stocks/us/consumer-services/nasdaq-aacg/ata-c...   AACG          NaN
# 164  /stocks/us/consumer-services/nyse-stg/sunlands...    STG          NaN
# 165     /stocks/us/consumer-services/nasdaq-xwel/xwell   XWEL          NaN
# 166  /stocks/us/consumer-services/nysemkt-bdl/flani...    BDL     ($14.24)
# 167  /stocks/us/consumer-services/nasdaq-tedu/taren...   TEDU          NaN
#
# [168 rows x 3 columns]
#                                                   href  ticker    fair_value
# 0    /stocks/us/diversified-financials/nyse-brk.a/b...   BRK.A   ($513344.6)
# 1    /stocks/us/diversified-financials/nyse-ms/morg...      MS     ($107.19)
# 2    /stocks/us/diversified-financials/nyse-schw/ch...    SCHW      ($95.22)
# 3    /stocks/us/diversified-financials/nyse-gs/gold...      GS      ($327.6)
# 4    /stocks/us/diversified-financials/nyse-axp/ame...     AXP     ($213.73)
# ..                                                 ...     ...           ...
# 163  /stocks/us/diversified-financials/nyse-goac/go...    GOAC           NaN
# 164  /stocks/us/diversified-financials/nasdaq-lmac....  LMAC.A           NaN
# 165  /stocks/us/diversified-financials/nasdaq-lgac/...    LGAC           NaN
# 166  /stocks/us/diversified-financials/nasdaq-msda/...    MSDA           NaN
# 167  /stocks/us/diversified-financials/nasdaq-slam/...    SLAM           NaN
#
# [168 rows x 3 columns]
#                                                 href ticker  fair_value
# 0             /stocks/us/energy/nyse-xom/exxon-mobil    XOM   ($100.87)
# 1                 /stocks/us/energy/nyse-cvx/chevron    CVX   ($152.98)
# 2          /stocks/us/energy/nyse-cop/conocophillips    COP     ($72.8)
# 3           /stocks/us/energy/nyse-eog/eog-resources    EOG    ($72.48)
# 4            /stocks/us/energy/nyse-slb/schlumberger    SLB    ($53.33)
# ..                                               ...    ...         ...
# 91          /stocks/us/energy/nasdaq-rocc/ranger-oil   ROCC    ($23.51)
# 92       /stocks/us/energy/nyse-gpor/gulfport-energy   GPOR   ($232.27)
# 93          /stocks/us/energy/nyse-talo/talos-energy   TALO   ($217.21)
# 94  /stocks/us/energy/nasdaq-clne/clean-energy-fuels   CLNE    ($22.36)
# 95      /stocks/us/energy/nyse-nbr/nabors-industries    NBR   ($507.99)
#
# [96 rows x 3 columns]
#                                                   href ticker  fair_value
# 0    /stocks/us/food-beverage-tobacco/nyse-ko/coca-...     KO    ($80.39)
# 1    /stocks/us/food-beverage-tobacco/nasdaq-pep/pe...    PEP   ($195.78)
# 2    /stocks/us/food-beverage-tobacco/nyse-pm/phili...     PM   ($181.26)
# 3    /stocks/us/food-beverage-tobacco/nasdaq-mdlz/m...   MDLZ    ($91.96)
# 4    /stocks/us/food-beverage-tobacco/nyse-mo/altri...     MO    ($89.64)
# ..                                                 ...    ...         ...
# 109  /stocks/us/food-beverage-tobacco/nasdaq-nuze/n...   NUZE         NaN
# 110  /stocks/us/food-beverage-tobacco/nasdaq-kal/ka...    KAL         NaN
# 111  /stocks/us/food-beverage-tobacco/nysemkt-wbev/...   WBEV         NaN
# 112  /stocks/us/food-beverage-tobacco/nasdaq-east/e...   EAST         NaN
# 113  /stocks/us/food-beverage-tobacco/nasdaq-edbl/e...   EDBL         NaN
#
# [114 rows x 3 columns]
#                                                   href ticker  fair_value
# 0    /stocks/us/healthcare/nyse-unh/unitedhealth-group    UNH   ($802.92)
# 1    /stocks/us/healthcare/nyse-abt/abbott-laborato...    ABT   ($130.99)
# 2            /stocks/us/healthcare/nyse-cvs/cvs-health    CVS   ($192.18)
# 3       /stocks/us/healthcare/nyse-elv/elevance-health    ELV   ($703.63)
# 4             /stocks/us/healthcare/nyse-mdt/medtronic    MDT   ($109.31)
# ..                                                 ...    ...         ...
# 163  /stocks/us/healthcare/nasdaq-csii/cardiovascul...   CSII         NaN
# 164       /stocks/us/healthcare/nasdaq-hlth/cue-health   HLTH    ($11.77)
# 165    /stocks/us/healthcare/nasdaq-ango/angiodynamics   ANGO         NaN
# 166  /stocks/us/healthcare/nysemkt-sens/senseonics-...   SENS         NaN
# 167  /stocks/us/healthcare/nasdaq-cstl/castle-biosc...   CSTL   ($115.85)
#
# [168 rows x 3 columns]
#                                                  href ticker  fair_value
# 0         /stocks/us/household/nyse-pg/procter-gamble     PG    ($178.7)
# 1   /stocks/us/household/nyse-el/estee-lauder-comp...     EL   ($216.87)
# 2      /stocks/us/household/nyse-cl/colgate-palmolive     CL   ($116.97)
# 3        /stocks/us/household/nyse-kmb/kimberly-clark    KMB   ($164.56)
# 4         /stocks/us/household/nyse-chd/church-dwight    CHD    ($98.18)
# 5                /stocks/us/household/nyse-clx/clorox    CLX   ($201.85)
# 6                 /stocks/us/household/nyse-coty/coty   COTY    ($13.44)
# 7   /stocks/us/household/nasdaq-reyn/reynolds-cons...   REYN    ($33.56)
# 8   /stocks/us/household/nasdaq-olpx/olaplex-holdings   OLPX     ($13.5)
# 9      /stocks/us/household/nyse-brbr/bellring-brands   BRBR    ($22.77)
# 10     /stocks/us/household/nasdaq-ipar/inter-parfums   IPAR    ($37.64)
# 11           /stocks/us/household/nyse-elf/elf-beauty    ELF    ($40.07)
# 12             /stocks/us/household/nasdaq-wdfc/wd-40   WDFC    ($76.02)
# 13  /stocks/us/household/nasdaq-cent/central-garde...   CENT    ($55.34)
# 14   /stocks/us/household/nyse-enr/energizer-holdings    ENR   ($126.98)
# 15  /stocks/us/household/nyse-spb/spectrum-brands-...    SPB   ($181.32)
# 16  /stocks/us/household/nyse-epc/edgewell-persona...    EPC    ($45.33)
# 17  /stocks/us/household/nyse-nus/nu-skin-enterprises    NUS   ($117.23)
# 18  /stocks/us/household/nyse-hlf/herbalife-nutrition    HLF    ($33.11)
# 19     /stocks/us/household/nasdaq-skin/beauty-health   SKIN    ($14.18)
# 20             /stocks/us/household/nyse-med/medifast    MED   ($136.22)
# 21        /stocks/us/household/nasdaq-wald/waldencast   WALD     ($8.88)
# 22  /stocks/us/household/nyse-usna/usana-health-sc...   USNA    ($74.09)
# 23       /stocks/us/household/nyse-ysg/yatsen-holding    YSG     ($2.58)
# 24              /stocks/us/household/nasdaq-veru/veru   VERU    ($23.12)
# 25            /stocks/us/household/nasdaq-hnst/honest   HNST     ($9.43)
# 26  /stocks/us/household/nyse-odc/oil-dri-corporat...    ODC    ($27.29)
# 27  /stocks/us/household/nasdaq-thrn/thorne-health...   THRN         NaN
# 28  /stocks/us/household/nasdaq-natr/natures-sunsh...   NATR    ($28.58)
# 29    /stocks/us/household/nasdaq-obci/ocean-bio-chem   OBCI     ($4.72)
# 30             /stocks/us/household/nasdaq-upxi/upexi   UPXI         NaN
# 31            /stocks/us/household/nasdaq-lfmd/lifemd   LFMD         NaN
# 32  /stocks/us/household/nasdaq-nhtc/natural-healt...   NHTC     ($5.58)
# 33     /stocks/us/household/nasdaq-ug/united-guardian     UG     ($14.4)
# 34       /stocks/us/household/nasdaq-lfvn/lifevantage   LFVN     ($1.91)
# 35  /stocks/us/household/nasdaq-naii/natural-alter...   NAII         NaN
# 36      /stocks/us/household/nasdaq-flgc/flora-growth   FLGC     ($3.33)
# 37         /stocks/us/household/nasdaq-mtex/mannatech   MTEX    ($15.06)
# 38  /stocks/us/household/nasdaq-jupw/jupiter-wellness   JUPW    ($41.65)
# 39   /stocks/us/household/nasdaq-zivo/zivo-bioscience   ZIVO         NaN
# 40     /stocks/us/household/nasdaq-sumr/summer-infant   SUMR         NaN
# 41           /stocks/us/household/nasdaq-sisi/shineco   SISI         NaN
# 42    /stocks/us/household/nasdaq-smfl/smart-for-life   SMFL         NaN
# 43  /stocks/us/household/nasdaq-nept/neptune-welln...   NEPT         NaN
# 44  /stocks/us/household/nasdaq-ghsi/guardion-heal...   GHSI         NaN
# 45  /stocks/us/household/nasdaq-happ/happiness-dev...   HAPP         NaN
# 46         /stocks/us/household/nasdaq-cyan/cyanotech   CYAN      ($4.8)
# 47  /stocks/us/household/nasdaq-brsh/bruush-oral-care   BRSH    ($22.48)
#                                                   href ticker  fair_value
# 0                   /stocks/us/insurance/nyse-cb/chubb     CB    ($329.4)
# 1    /stocks/us/insurance/nyse-mmc/marsh-mclennan-c...    MMC   ($173.27)
# 2            /stocks/us/insurance/nyse-pgr/progressive    PGR   ($128.76)
# 3                    /stocks/us/insurance/nyse-aon/aon    AON   ($311.04)
# 4                /stocks/us/insurance/nyse-met/metlife    MET   ($102.63)
# ..                                                 ...    ...         ...
# 105  /stocks/us/insurance/nasdaq-oxbr/oxbridge-re-h...   OXBR         NaN
# 106  /stocks/us/insurance/nasdaq-uihc/united-insura...   UIHC         NaN
# 107  /stocks/us/insurance/nasdaq-reli/reliance-glob...   RELI         NaN
# 108  /stocks/us/insurance/nasdaq-tirx/tian-ruixiang...   TIRX         NaN
# 109    /stocks/us/insurance/nasdaq-unam/unico-american   UNAM         NaN
#
# [110 rows x 3 columns]
#                                                   href ticker  fair_value
# 0                  /stocks/us/materials/nyse-lin/linde    LIN   ($215.29)
# 1    /stocks/us/materials/nyse-apd/air-products-and...    APD   ($891.77)
# 2       /stocks/us/materials/nyse-shw/sherwin-williams    SHW   ($236.52)
# 3       /stocks/us/materials/nyse-fcx/freeport-mcmoran    FCX   ($108.17)
# 4       /stocks/us/materials/nyse-scco/southern-copper   SCCO    ($78.12)
# ..                                                 ...    ...         ...
# 162   /stocks/us/materials/nyse-vntr/venator-materials   VNTR     ($1.17)
# 163        /stocks/us/materials/nysemkt-vgz/vista-gold    VGZ         NaN
# 164  /stocks/us/materials/nyse-cga/china-green-agri...    CGA         NaN
# 165  /stocks/us/materials/nasdaq-usap/universal-sta...   USAP    ($30.17)
# 166  /stocks/us/materials/nysemkt-idr/idaho-strateg...    IDR         NaN
#
# [167 rows x 3 columns]
#                                                href ticker  fair_value
# 0            /stocks/us/media/nasdaq-googl/alphabet   GOOG   ($187.43)
# 1       /stocks/us/media/nasdaq-meta/meta-platforms   META   ($419.81)
# 2             /stocks/us/media/nyse-dis/walt-disney    DIS   ($156.31)
# 3             /stocks/us/media/nasdaq-cmcsa/comcast  CMCSA     ($87.8)
# 4              /stocks/us/media/nasdaq-nflx/netflix   NFLX   ($393.69)
# ..                                              ...    ...         ...
# 162  /stocks/us/media/nasdaq-blct/bluecity-holdings   BLCT         NaN
# 163               /stocks/us/media/nasdaq-gaia/gaia   GAIA         NaN
# 164    /stocks/us/media/nyse-feng/phoenix-new-media   FENG         NaN
# 165   /stocks/us/media/nasdaq-lylt/loyalty-ventures   LYLT    ($20.43)
# 166                /stocks/us/media/nyse-aud/audacy    AUD    ($11.28)
#
# [167 rows x 3 columns]
#                                                   href ticker  fair_value
# 0    /stocks/us/pharmaceuticals-biotech/nyse-jnj/jo...    JNJ   ($213.78)
# 1    /stocks/us/pharmaceuticals-biotech/nyse-lly/el...    LLY   ($344.57)
# 2    /stocks/us/pharmaceuticals-biotech/nyse-pfe/pf...    PFE   ($104.09)
# 3    /stocks/us/pharmaceuticals-biotech/nyse-abbv/a...   ABBV   ($308.36)
# 4    /stocks/us/pharmaceuticals-biotech/nyse-mrk/merck    MRK   ($209.73)
# ..                                                 ...    ...         ...
# 162  /stocks/us/pharmaceuticals-biotech/nasdaq-mdgl...   MDGL    ($20.49)
# 163  /stocks/us/pharmaceuticals-biotech/nasdaq-morf...   MORF         NaN
# 164  /stocks/us/pharmaceuticals-biotech/nasdaq-zntl...   ZNTL         NaN
# 165  /stocks/us/pharmaceuticals-biotech/nasdaq-tgtx...   TGTX   ($141.95)
# 166  /stocks/us/pharmaceuticals-biotech/nasdaq-acrs...   ACRS         NaN
#
# [167 rows x 3 columns]
#                                                   href ticker   fair_value
# 0             /stocks/us/real-estate/nyse-pld/prologis    PLD    ($162.02)
# 1       /stocks/us/real-estate/nyse-amt/american-tower    AMT    ($320.27)
# 2           /stocks/us/real-estate/nasdaq-eqix/equinix   EQIX   ($1055.08)
# 3         /stocks/us/real-estate/nyse-cci/crown-castle    CCI    ($165.81)
# 4       /stocks/us/real-estate/nyse-psa/public-storage    PSA    ($461.42)
# ..                                                 ...    ...          ...
# 162    /stocks/us/real-estate/nyse-wsr/whitestone-reit    WSR     ($12.45)
# 163          /stocks/us/real-estate/nasdaq-rdfn/redfin   RDFN     ($14.81)
# 164  /stocks/us/real-estate/nyse-ht/hersha-hospital...     HT     ($41.41)
# 165     /stocks/us/real-estate/nyse-brt/brt-apartments    BRT      ($40.1)
# 166   /stocks/us/real-estate/nyse-cio/city-office-reit    CIO     ($12.91)
#
# [167 rows x 3 columns]
#                                                   href ticker  fair_value
# 0              /stocks/us/retail/nasdaq-amzn/amazoncom   AMZN   ($244.96)
# 1                 /stocks/us/retail/nyse-hd/home-depot     HD   ($321.48)
# 2    /stocks/us/retail/nyse-baba/alibaba-group-holding   BABA   ($148.11)
# 3           /stocks/us/retail/nyse-low/lowes-companies    LOW   ($299.91)
# 4             /stocks/us/retail/nyse-tjx/tjx-companies    TJX    ($62.76)
# ..                                                 ...    ...         ...
# 160          /stocks/us/retail/nysemkt-bgi/birks-group    BGI    ($48.16)
# 161  /stocks/us/retail/nasdaq-kxin/kaixin-auto-hold...   KXIN         NaN
# 162            /stocks/us/retail/nasdaq-hour/hour-loop   HOUR         NaN
# 163                /stocks/us/retail/nyse-expr/express   EXPR         NaN
# 164              /stocks/us/retail/nasdaq-tdup/thredup   TDUP         NaN
#
# [165 rows x 3 columns]
#                                                   href ticker  fair_value
# 0         /stocks/us/semiconductors/nasdaq-nvda/nvidia   NVDA   ($157.62)
# 1       /stocks/us/semiconductors/nasdaq-avgo/broadcom   AVGO   ($544.88)
# 2    /stocks/us/semiconductors/nasdaq-txn/texas-ins...    TXN   ($180.33)
# 3       /stocks/us/semiconductors/nasdaq-qcom/qualcomm   QCOM   ($170.01)
# 4          /stocks/us/semiconductors/nasdaq-intc/intel   INTC    ($21.72)
# ..                                                 ...    ...         ...
# 96        /stocks/us/semiconductors/nasdaq-prso/peraso   PRSO         NaN
# 97   /stocks/us/semiconductors/nysemkt-trt/trio-tec...    TRT     ($0.52)
# 98      /stocks/us/semiconductors/nasdaq-leds/semileds   LEDS         NaN
# 99   /stocks/us/semiconductors/nasdaq-wisa/wisa-tec...   WISA         NaN
# 100  /stocks/us/semiconductors/nasdaq-rbcn/rubicon-...   RBCN         NaN
#
# [101 rows x 3 columns]
#                                                   href ticker  fair_value
# 0            /stocks/us/software/nasdaq-msft/microsoft   MSFT   ($303.08)
# 1                      /stocks/us/software/nyse-v/visa      V   ($217.96)
# 2               /stocks/us/software/nyse-ma/mastercard     MA   ($380.69)
# 3                 /stocks/us/software/nyse-orcl/oracle   ORCL   ($115.26)
# 4               /stocks/us/software/nyse-acn/accenture    ACN   ($322.91)
# ..                                                 ...    ...         ...
# 163       /stocks/us/software/nyse-kd/kyndryl-holdings     KD    ($42.22)
# 164      /stocks/us/software/nasdaq-aciw/aci-worldwide   ACIW    ($36.16)
# 165              /stocks/us/software/nyse-evtc/evertec   EVTC    ($22.29)
# 166  /stocks/us/software/nasdaq-prgs/progress-software   PRGS    ($87.72)
# 167              /stocks/us/software/nasdaq-frog/jfrog   FROG    ($16.38)
#
# [168 rows x 3 columns]
#                                                   href ticker  fair_value
# 0                    /stocks/us/tech/nasdaq-aapl/apple   AAPL   ($138.63)
# 1            /stocks/us/tech/nasdaq-csco/cisco-systems   CSCO    ($71.52)
# 2                    /stocks/us/tech/nyse-aph/amphenol    APH    ($66.08)
# 3          /stocks/us/tech/nyse-msi/motorola-solutions    MSI   ($266.65)
# 4             /stocks/us/tech/nyse-tel/te-connectivity    TEL   ($127.05)
# ..                                                 ...    ...         ...
# 163       /stocks/us/tech/nysemkt-bkti/bk-technologies   BKTI     ($0.57)
# 164  /stocks/us/tech/nasdaq-tact/transact-technologies   TACT         NaN
# 165      /stocks/us/tech/nasdaq-fkwl/franklin-wireless   FKWL         NaN
# 166    /stocks/us/tech/nasdaq-snt/senstar-technologies    SNT     ($3.91)
# 167            /stocks/us/tech/nyse-viao/via-optronics   VIAO     ($2.07)
#
# [168 rows x 3 columns]
#                                                  href  ticker   fair_value
# 0          /stocks/us/telecom/nasdaq-tmus/t-mobile-us    TMUS    ($403.93)
# 1   /stocks/us/telecom/nyse-vz/verizon-communications      VZ    ($138.73)
# 2                       /stocks/us/telecom/nyse-t/att       T     ($79.24)
# 3     /stocks/us/telecom/nasdaq-lbty.a/liberty-global  LBTY.A     ($54.05)
# 4     /stocks/us/telecom/nyse-lumn/lumen-technologies    LUMN      ($7.11)
# 5   /stocks/us/telecom/nasdaq-irdm/iridium-communi...    IRDM     ($74.23)
# 6   /stocks/us/telecom/nasdaq-fybr/frontier-commun...    FYBR          NaN
# 7          /stocks/us/telecom/nysemkt-gsat/globalstar    GSAT      ($2.21)
# 8   /stocks/us/telecom/nasdaq-ccoi/cogent-communic...    CCOI      ($76.3)
# 9   /stocks/us/telecom/nasdaq-tigo/millicom-intern...    TIGO     ($60.51)
# 10            /stocks/us/telecom/nyse-ihs/ihs-holding     IHS      ($25.9)
# 11                /stocks/us/telecom/nasdaq-gogo/gogo    GOGO     ($40.78)
# 12  /stocks/us/telecom/nyse-usm/united-states-cell...     USM    ($928.88)
# 13  /stocks/us/telecom/nasdaq-lila/liberty-latin-a...    LILA     ($29.54)
# 14            /stocks/us/telecom/nasdaq-sats/echostar    SATS      ($5.68)
# 15  /stocks/us/telecom/nasdaq-ptnr/partner-communi...    PTNR     ($15.49)
# 16     /stocks/us/telecom/nasdaq-asts/ast-spacemobile    ASTS   ($1098.68)
# 17  /stocks/us/telecom/nyse-tds/telephone-and-data...     TDS     ($15.21)
# 18  /stocks/us/telecom/nasdaq-radi/radius-global-i...    RADI          NaN
# 19  /stocks/us/telecom/nasdaq-shen/shenandoah-tele...    SHEN      ($1.48)
# 20   /stocks/us/telecom/nasdaq-atni/atn-international    ATNI    ($299.73)
# 21             /stocks/us/telecom/nasdaq-atex/anterix    ATEX    ($917.85)
# 22                /stocks/us/telecom/nasdaq-veon/veon    VEON       ($8.7)
# 23                    /stocks/us/telecom/nyse-idt/idt     IDT      ($0.38)
# 24  /stocks/us/telecom/nasdaq-cnsl/consolidated-co...    CNSL     ($58.43)
# 25           /stocks/us/telecom/nasdaq-band/bandwidth    BAND      ($9.67)
# 26  /stocks/us/telecom/nasdaq-crge/charge-enterprises    CRGE      ($9.22)
# 27                  /stocks/us/telecom/nyse-ooma/ooma    OOMA     ($55.86)
# 28   /stocks/us/telecom/nasdaq-sify/sify-technologies    SIFY          NaN
# 29        /stocks/us/telecom/nasdaq-fngr/fingermotion    FNGR          NaN
# 30   /stocks/us/telecom/nyse-kore/kore-group-holdings    KORE     ($22.91)
# 31       /stocks/us/telecom/nasdaq-spok/spok-holdings    SPOK      ($4.97)
# 32           /stocks/us/telecom/nasdaq-surg/surgepays    SURG          NaN
# 33     /stocks/us/telecom/nasdaq-ucl/ucloudlink-group     UCL          NaN
# 34  /stocks/us/telecom/nyse-stry/starry-group-hold...    STRY          NaN
# 35            /stocks/us/telecom/nasdaq-nxpl/nextplat    NXPL          NaN
# 36             /stocks/us/telecom/nasdaq-cuen/cuentas    CUEN          NaN
#                                                   href ticker  fair_value
# 0    /stocks/us/transportation/nyse-ups/united-parc...    UPS   ($189.39)
# 1     /stocks/us/transportation/nyse-unp/union-pacific    UNP   ($192.96)
# 2             /stocks/us/transportation/nasdaq-csx/csx    CSX    ($29.92)
# 3    /stocks/us/transportation/nyse-nsc/norfolk-sou...    NSC   ($226.38)
# 4    /stocks/us/transportation/nyse-uber/uber-techn...   UBER    ($59.57)
# ..                                                 ...    ...         ...
# 96   /stocks/us/transportation/nasdaq-pshg/performa...   PSHG         NaN
# 97        /stocks/us/transportation/nasdaq-hlbz/helbiz   HLBZ         NaN
# 98   /stocks/us/transportation/nasdaq-ezgo/ezgo-tec...   EZGO         NaN
# 99        /stocks/us/transportation/nasdaq-op/oceanpal     OP         NaN
# 100  /stocks/us/transportation/nasdaq-frgt/freight-...   FRGT         NaN
#
# [101 rows x 3 columns]
#                                                  href ticker  fair_value
# 0        /stocks/us/utilities/nyse-nee/nextera-energy    NEE    ($38.19)
# 1           /stocks/us/utilities/nyse-duk/duke-energy    DUK    ($77.49)
# 2               /stocks/us/utilities/nyse-so/southern     SO   ($121.78)
# 3         /stocks/us/utilities/nyse-d/dominion-energy      D   ($112.71)
# 4                /stocks/us/utilities/nyse-sre/sempra    SRE   ($123.59)
# ..                                                ...    ...         ...
# 75     /stocks/us/utilities/nasdaq-rgco/rgc-resources   RGCO    ($19.01)
# 76        /stocks/us/utilities/nasdaq-pcyo/pure-cycle   PCYO         NaN
# 77             /stocks/us/utilities/nasdaq-cdzi/cadiz   CDZI         NaN
# 78  /stocks/us/utilities/nasdaq-wave/eco-wave-powe...   WAVE         NaN
# 79  /stocks/us/utilities/nasdaq-vvpr/vivopower-int...   VVPR         NaN
#
# [80 rows x 3 columns]

# %%
from datetime import datetime
import yfinance as yf
import json

def find_transcript(ticker, date_yr, date_qtr, i):
    try:
        url = 'https://roic.ai/transcripts/' + ticker + '?y=' + str(date_yr) + '&q=' + str(date_qtr)
        html_text = requests.get(url).text
        soup = BeautifulSoup(html_text, "html.parser")
        # site below is used to visualise JSON files (indented)
        # https://jsonformatter.org/
        # finds the 15th <script/> and strips the unnecsssary data so it can be read in JSON
        script = soup.find_all('script')[15].text.strip()  
        data = json.loads(script)
        transcript_data = data['props']['pageProps']['transcriptdata']['content']  # loads the transcript content
        exact_date = datetime.strptime(data['props']['pageProps']['data']['data']['earningscalls'][i]['date'], '%Y-%m-%d %H:%M:%S')
        #exact_date = 'day 0', earnings transcript release date
        ntr = yf.Ticker(ticker)
    except:
        transcript_data = np.NaN
        exact_date = np.NaN
        
    return transcript_data, exact_date

def ticker_transcript(ticker):
    #loops around each ticker, feature extracts each by calling relevant functions below
    try:
        url = 'https://roic.ai/transcripts/' + ticker

        html_text = requests.get(url).text
        soup = BeautifulSoup(html_text, "html.parser")

        script = soup.find_all('script')[15].text.strip()
        # finds json data (i.e. transcript)
        data = json.loads(script)
        first_er_date = data['props']['pageProps']['data']['data']['earningscalls'][0]
        last_er_date = data['props']['pageProps']['data']['data']['earningscalls'][-1]
        # reads the json data and finds the first and last date for which the transcript is held and its set as limits
        # perhaps I worded it badly...
        # first_er_date_yr represents the most recent transcript's date (i.e. 2022)
        # last_er_date represents the last transcript's date (e.g. 2006)

        first_er_date_yr = first_er_date['year'] 
        first_er_date_qtr = first_er_date['quarter']
        last_er_date_yr = last_er_date['year']
        # calculates the year differences between the dates of first and last transcript so it can be looped
        yr_difference = first_er_date_yr-last_er_date_yr
        date_yr = first_er_date_yr
        date_qtr = first_er_date_qtr

        arr_ticker_infos = np.empty((0, 4), str)
        arr_full_transcript = np.array([], str) #array of all of the transcripts, every year and quarter
        q = -1

        for i in range(0, yr_difference + 1):
            #there are two seperate loops below:
            if date_yr == first_er_date_yr:
                # the first loop is to loop through the most recent transcript as the quarter does not end with 4
                # as of when this programme is written, the most recent transcript is Q2 of 2022
                for j in range(0, first_er_date_qtr):
                    q += 1
                    #finds the relevant 13 initial dataset as described in page 2 of the Doc
                    #it finds them by calling the function find_transcript() located below
                    full_transcript, exact_date = find_transcript(ticker, date_yr, date_qtr, q)
                    arr_full_transcript = np.append(arr_full_transcript, full_transcript)
                    arr_ticker_infos = np.append(arr_ticker_infos, np.array([[ticker, date_yr, date_qtr, exact_date]]), axis=0)
                    date_qtr -= 1
                    if date_qtr == 0:
                        date_qtr = 4
            else:
                # the second loop loops through the rest of the transcripts
                for j in range(0, 4):
                    q += 1
                    
                    full_transcript, exact_date = find_transcript(ticker, date_yr, date_qtr, q)
                    arr_full_transcript = np.append(arr_full_transcript, full_transcript)
                    arr_ticker_infos = np.append(arr_ticker_infos, np.array([[ticker, date_yr, date_qtr, exact_date]]), axis=0)

                    date_qtr -= 1
                    if date_qtr == 0:
                        date_qtr = 4
            date_yr -= 1
    except:
        arr_full_transcript = np.NaN
        arr_ticker_infos = np.NaN
        
    return arr_full_transcript, arr_ticker_infos

# %%
import os

sectorlist = ["automobiles", "banks", "capital-goods", "commercial-services", 
"consumer-durables", "consumer-retailing", "consumer-services", "diversified-financials",
"energy", "food-beverage-tobacco", "healthcare", "household", "insurance", "materials", "media", 
"pharmaceuticals-biotech", "real-estate", "retail", "semiconductors", "software",
"tech", "telecom", "transportation", "utilities"]
for sector in sectorlist:
    df_stock_list = pd.read_csv('hrefs/ref_'+sector+'.csv')['ticker']
    for stock in df_stock_list:
        try:
            try: 
                filelist = os.listdir("sectors/"+sector)
            except:
                filelist = []

            if stock not in filelist:
                print(stock)

                arr_full_transcript, arr_ticker_infos = ticker_transcript(stock)
                FOLDERPATH = 'sectors/' + sector + '/' + str(stock)
                if not os.path.exists(FOLDERPATH):
                    os.makedirs(FOLDERPATH)
                for i in range(0,len(arr_ticker_infos)):
                    year = arr_ticker_infos[i][1]
                    quarter = arr_ticker_infos[i][2]
                    release_date = arr_ticker_infos[i][3]
                    single_transcript = arr_full_transcript[i]
                    df_transcript_details = pd.DataFrame([year, quarter, release_date, single_transcript])
                    FILEPATH = 'sectors/' + sector + '/' + str(stock) + '/' + str(stock) + str(year) + str(quarter) + ".csv"
                    df_transcript_details.to_csv(FILEPATH, header=False, index=False)
        except:
            continue
        
    # break
# Out:
# nan

# %%
for every stock transcript if the third index is na:
     delete
